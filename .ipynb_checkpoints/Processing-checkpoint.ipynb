# %%
# import files
from threading import Thread
import queue as que
import pandas as pd
import os, pickle
import nltk
import math
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
stemmer = SnowballStemmer("english")
cachedStopWords = stopwords.words("english")

# %%
# methods
def read(fileName):
    with open(fileName) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    return content

def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

def seperator(docs):
    print(len(docs))
    txt = []
    typesInfo = []
    docsInfo = []
    for line in docs:
        words = line.split()
        content = (" ").join(words[1:])
        item = (", ").join([words[0], content])
        txt.append(item)
        typesInfo.append(words[0])
        docsInfo.append(content)
        
        
    return txt, typesInfo, docsInfo

def write(data):
    print(type(data))
    with open('./training_data.csv', 'w') as f:
        for item in data:
            f.write("%s\n" % item)
            
            
def save_it_all(obj, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
    
def load_objects(file):
    with open(file, 'rb') as input:
        return pickle.load(input)
    
def vocabDict(vocab, dataframe):
    
    nk = 0
    n = dataframe["Word Positions"][dataframe["Type"]==docType].tolist()[0]
    probability = math.log(nk + 1) - math.log(n + len(vocab))

    newDict = {"count": 0, "probability":probability}
    vdict = dict((el,newDict) for el in vocab)
    return vdict

def wordCount(dataframe, vocab):
    for docType in dataframe['Type']:
        counts = [dict(Counter(dataframe["document"][dataframe["Type"]==docType].tolist()[0].split()))]
        emptyVocab = vocabDict(vocab, dataframe)
        dataframe["wordCount"][dataframe["Type"]==docType] = [merge_two_dicts(emptyVocab, counts[0])]
    
    return dataframe

def wordProbs(dataFrame):
    for docType in dataFrame["Type"]:
        wordCountDict = dataFrame["wordCount"][dataFrame["Type"]==docType].tolist()[0]
        for key in wordCountDict:
            nk = dataFrame["wordCount"][dataFrame["Type"]==docType].tolist()[0][key]
            n = dataFrame["Word Positions"][dataFrame["Type"]==docType].tolist()[0]
            probability = math.log(nk + 1) - math.log(n + len(vocabStopStemmingEdit))
            newDict = {"count": nk, "probability":probability}
            dataFrame["wordCount"][dataFrame["Type"]==docType].tolist()[0][key] = newDict
    return dataFrame

# %%
# main
# test extracting the vocabulary and data frame creation
# read file line by line 
fileName = "forumTraining.data"
types = ['atheism','baseball', 'christianity', 'pc', 'guns', 'mideastpolitics', 'mac', 'electronics', 'forsale', 'autos', 'graphics', 'religion', 'xwindows','hockey', 'motorcycles', 'mswindows', 'cryptology', 'space', 'politics','medicine']

#dataFrameInitial = pd.DataFrame()

# pd.DataFrame(
#     {'lst1Title': lst1,
#      'lst2Title': lst2,
#      'lst3Title': lst3
#     })
# main:
data = read(fileName)
sep_data, typesInfo, docsInfo = seperator(data)
write(sep_data)
print(list(set(typesInfo)))
# dataFrameInitial = pd.DataFrame({"Type": typesInfo, "Document": docsInfo})

# columns should be the type and index should be the vocabulary
# Out:
# 11293
# <class 'list'>
# ['atheism', 'baseball', 'christianity', 'pc', 'guns', 'mideastpolitics', 'mac', 'electronics', 'forsale', 'autos', 'graphics', 'religion', 'xwindows', 'hockey', 'motorcycles', 'mswindows', 'cryptology', 'space', 'politics', 'medicine']

# %%
dataFrameInitial.to_csv("TraindataFrameInitial.csv", index=False, sep=",", header=True)
dataFrameInitial.head(430)
testInfo = pd.read_csv("./TraindataFrameInitial.csv", sep=",")
testInfo.head(430)
# Out:
#         Type                                           Document
# 0    atheism  alt atheism faq atheist resources archive name...
# 1    atheism  alt atheism faq introduction to atheism archiv...
# 2    atheism  re gospel dating in article mimsy umd edu mang...
# 3    atheism  re university violating separation of church s...
# 4    atheism  re soc motss et al princeton axes matching fun...
# 5    atheism  re a visit from the jehovah s witnesses in art...
# 6    atheism  re political atheists arromdee jyusenkyou cs j...
# 7    atheism  re an anecdote about islam in article bu edu j...
# 8    atheism  re political atheists reference line trimmed l...
# 9    atheism  re pompous ass kmr po cwru edu keith m ryan wr...
# 10   atheism  re pompous ass livesey solntze wpd sgi com jon...
# 11   atheism  re keith schneider stealth poster sandvik newt...
# 12   atheism  re keith schneider stealth poster arromdee jyu...
# 13   atheism  re political atheists bobbe vice ico tek com r...
# 14   atheism  re political atheists bobbe vice ico tek com r...
# 15   atheism  re political atheists bobbe vice ico tek com r...
# 16   atheism  re don t more innocents die without the death ...
# 17   atheism  re ancient islamic rituals in article apr monu...
# 18   atheism  re political atheists in article apr blaze cs ...
# 19   atheism  re there must be a creator maybe in article ba...
# 20   atheism  re americans and evolution in article j l rpi ...
# 21   atheism  re speculations in article w rusnews w w manti...
# 22   atheism  re political atheists livesey solntze wpd sgi ...
# 23   atheism  re political atheists livesey solntze wpd sgi ...
# 24   atheism  re university violating separation of church s...
# 25   atheism  re usatoday ad family values in article c rzz ...
# 26   atheism  re islamic authority over women in article apr...
# 27   atheism  re ancient islamic rituals in article apr monu...
# 28   atheism  re soc motss et al princeton axes matching fun...
# 29   atheism  re political atheists mathew mathew mantis co ...
# ..       ...                                                ...
# 400  atheism  re americans and evolution robert singleton bo...
# 401  atheism  re amusing atheists and agnostics timmbake mcl...
# 402  atheism  re death penalty was re political athei in art...
# 403  atheism  re requests in article vice ico tek com bobbe ...
# 404  atheism  re studies on book of mormon in article snx en...
# 405  atheism  re societal basis for morality in article c pr...
# 406  atheism  re genocide is caused by atheism in article ap...
# 407  atheism  re free moral agency in article c pxqs lm dark...
# 408  atheism  re yet more rushdie re islamic law in article ...
# 409  atheism  re islamic authority over women in article apr...
# 410  atheism  re suggestion for resources faq date mon apr g...
# 411  atheism  re amusing atheists and agnostics date apr gmt...
# 412  atheism  re objective values v scientific accuracy was ...
# 413  atheism  re it s all mary s fault dfuller portal hq vid...
# 414  atheism  re islam and scientific predictions was in art...
# 415  atheism  re yet more rushdie re islamic law in article ...
# 416  atheism  re the inimitable rushdie re an anecdote about...
# 417  atheism  re jewish settlers demolish a mosque in gaza i...
# 418  atheism  nostalgia the recent rise of nostalgia in this...
# 419  atheism  re some thoughts bissda saturn wwc edu dan law...
# 420  atheism  re bible quiz in article apr ccsua ctstateu ed...
# 421  atheism  re islam and scientific predictions was in art...
# 422  atheism  bible contradictions i would like a list of bi...
# 423  atheism  re after years can we say that christian moral...
# 424  atheism  re a silly question on x tianity in article pw...
# 425  atheism  re islam and scientific predictions was umar k...
# 426  atheism  re the bible and abortion james j lippard lipp...
# 427  atheism  you will all go to hell you blashephemers you ...
# 428  atheism  re yet more rushdie re islamic law in article ...
# 429  atheism  re note to bobby m again in article apr ultb i...
#
# [430 rows x 2 columns]

# %%
# data frame set up 
df = pd.read_csv("./training_data.csv", sep=",", names=("Type","Document"))
df.head()
dataOriginal = df
# Docsj ← training documents for which the classification is cj
dataOriginal.head()
dataOriginal = testInfo.copy()

# %% [markdown]
# Collect all words occurring in the Sample documents
# • Vocabulary ← set of all distinct words

# %%
vocabulary = []
for line in dataOriginal["Document"]:
    for word in line.split():
        if word not in vocabulary:
            vocabulary.append(word)
print(len(vocabulary))
# Out:
# 73712

# %%
# save the vocabulary object
save_it_all(vocabulary, "./vocabulary.pkl")
vocabulary = load_objects("./vocabulary.pkl")
len(vocabulary)
"re" in vocabulary
# Out:
# True

# %% [markdown]
# For each class cj (document type) in C
#
# • Docsj ← training documents for which the classification is cj
#
# • Probability estimate of a particular class: P(cj) = |Docsj| / |training documents|
#
# • Textj ← create a single document per class (concatenate all Docsj)
#
# • n = total number of word positions in Textj
#
# • For each word wk in Vocabulary nk = number of times wk occurs in Textj
#
# • Estimate of word occurrence for particular document type:
#     P(wk | cj) = (nk + 1) / (n + |Vocabulary|)
#
# Probability of kth word in vocabulary, given a document of type j

# %%
# get the document types
types = list(set(dataOriginal["Type"].tolist()))
print(types)
# Out:
# ['atheism', 'baseball', 'christianity', 'pc', 'guns', 'mideastpolitics', 'mac', 'electronics', 'forsale', 'autos', 'graphics', 'religion', 'xwindows', 'hockey', 'motorcycles', 'mswindows', 'cryptology', 'space', 'politics', 'medicine']

# %%
# get the total count of document types
counts = []
for docType in types:
    counts.append(len(df.loc[dataOriginal['Type'] == docType]))
print("Total document records: "+str(len(dataOriginal['Type'])))

dataframeCounts = pd.DataFrame({'Type':types, 'Count':counts})

dataframeCounts.head(20)
# Out:
# Total document records: 11293
#                Type  Count
# 0           atheism    480
# 1          baseball    597
# 2      christianity    598
# 3                pc    590
# 4              guns    545
# 5   mideastpolitics    564
# 6               mac    578
# 7       electronics    591
# 8           forsale    585
# 9             autos    594
# 10         graphics    584
# 11         religion    377
# 12         xwindows    593
# 13           hockey    600
# 14      motorcycles    598
# 15        mswindows    572
# 16       cryptology    595
# 17            space    593
# 18         politics    465
# 19         medicine    594

# %%
# set the probablility for that document occuring in the set, 
# Probability estimate of a particular class: P(cj) = |Docsj| / |training documents|
dataInfo = dataframeCounts
dataInfo['Probablility'] = None 
# dataInfo = dataInfo.drop(columns="Probablility")
for docType in dataInfo["Type"]:
    dataInfo["Probablility"][dataInfo['Type'] == docType] = dataInfo["Count"][dataInfo["Type"]==docType]/len(dataOriginal['Type'])

dataInfo.head()
# Out:
#            Type  Count Probablility
# 0       atheism    480    0.0425042
# 1      baseball    597    0.0528646
# 2  christianity    598    0.0529532
# 3            pc    590    0.0522448
# 4          guns    545      0.04826

# %%
# Textj ← create a single document per class (concatenate all Docsj)
singleDocumentFrame = pd.DataFrame({'Type':types})
singleDocumentFrame["docData"] = None
for docType in dataInfo['Type']:
    singleDocumentFrame["docData"][singleDocumentFrame["Type"] == docType] = ' '.join(dataOriginal["Document"][dataOriginal["Type"] == docType].tolist())
    
    

dataOriginal # the original data set up no changes
vocabulary # the original vocab set of all the words in the original documents
dataInfo.head(5) # the counts and probability of the classes
singleDocumentFrame.head(5) # has all the athiesm docs in one spot.
# Out:
#            Type                                            docData
# 0       atheism  alt atheism faq atheist resources archive name...
# 1      baseball  spring records the orioles pitching staff agai...
# 2  christianity  re sex education in article mar athos rutgers ...
# 3            pc  wanted bus card for logitech mouse i ve acquir...
# 4          guns  re gun control was re we re mad as hell at the...

# %%
# adding documents to other frame
dataInfo["document"] = None
for docType in dataInfo["Type"]:
    dataInfo["document"][dataInfo["Type"] == docType] = singleDocumentFrame["docData"][singleDocumentFrame["Type"]==docType]
    
dataInfo.head()
  
    

# n = total number of word positions in Textj
dataInfo["Word Positions"] = None
for docType in dataInfo["Type"]:
    dataInfo["Word Positions"][dataInfo["Type"] == docType] = len(dataInfo["document"][dataInfo["Type"]==docType].tolist()[0].split())
    
dataInfo.head(20)

dataInfo.to_csv("dataInfoOriginal.csv", index=False, sep=",", header=True)
dataInfo.head(20)
dataEdit = dataInfo.copy()
dataEdit = wordProbs(dataEdit)

# %%
dataEdit.head()
dataEdit.to_csv("dataPredictedOriginal.csv", index=False, sep=",", header=True)
save_it_all(dataEdit)
dataEdit.head()
# Out:
#            Type  Count Probablility  \
# 0       atheism    480    0.0425042
# 1      baseball    597    0.0528646
# 2  christianity    598    0.0529532
# 3            pc    590    0.0522448
# 4          guns    545      0.04826
#
#                                            wordCount  \
# 0  {'alt': {'count': 89, 'probability': -7.867539...
# 1  {'spring': {'count': 40, 'probability': -8.456...
# 2  {'re': {'count': 598, 'probability': -6.182860...
# 3  {'wanted': {'count': 30, 'probability': -8.700...
# 4  {'re': {'count': 705, 'probability': -5.928937...
#
#                                             document Word Positions
# 0  alt atheism faq atheist resources archive name...         161442
# 1  spring records the orioles pitching staff agai...         119407
# 2  re sex education in article mar athos rutgers ...         216581
# 3  wanted bus card for logitech mouse i ve acquir...         112583
# 4  re gun control was re we re mad as hell at the...         191723

# %%
# For each word wk in Vocabulary nk = number of times wk occurs in Textj
for docType in dataInfo['Type']:
    dataInfo["wordCount"][dataInfo["Type"]==docType] = [dict(Counter(dataInfo["document"][dataInfo["Type"]==docType].tolist()[0].split()))]

# %%
# save the thing
dataInfo.to_csv("dataInfoOriginal.csv", index=False, sep=",", header=True)
save_it_all(dataInfo, "./dataInfo.pkl")

# %%
# load objects
dataInfo = load_objects("./dataInfo.pkl")
dataInfo.head()
# Out:
#            Type  Count Probablility  \
# 0       atheism    480    0.0425042
# 1      baseball    597    0.0528646
# 2  christianity    598    0.0529532
# 3            pc    590    0.0522448
# 4          guns    545      0.04826
#
#                                            wordCount  \
# 0  {'alt': 89, 'atheism': 301, 'faq': 66, 'atheis...
# 1  {'spring': 40, 'records': 6, 'the': 5561, 'ori...
# 2  {'re': 598, 'sex': 47, 'education': 30, 'in': ...
# 3  {'wanted': 30, 'bus': 316, 'card': 378, 'for':...
# 4  {'re': 705, 'gun': 975, 'control': 290, 'was':...
#
#                                             document Word Positions
# 0  alt atheism faq atheist resources archive name...         161442
# 1  spring records the orioles pitching staff agai...         119407
# 2  re sex education in article mar athos rutgers ...         216581
# 3  wanted bus card for logitech mouse i ve acquir...         112583
# 4  re gun control was re we re mad as hell at the...         191723

# %%
# access word count in dataframe dict
dataInfo["wordCount"][dataInfo["Type"]==docType].tolist()[0]['info']
# Out:
#            Type  Count Probablility  \
# 0       atheism    480    0.0425042
# 1      baseball    597    0.0528646
# 2  christianity    598    0.0529532
# 3            pc    590    0.0522448
# 4          guns    545      0.04826
#
#                                            wordCount  \
# 0  {'alt': 89, 'atheism': 301, 'faq': 66, 'atheis...
# 1  {'spring': 40, 'records': 6, 'the': 5561, 'ori...
# 2  {'re': 598, 'sex': 47, 'education': 30, 'in': ...
# 3  {'wanted': 30, 'bus': 316, 'card': 378, 'for':...
# 4  {'re': 705, 'gun': 975, 'control': 290, 'was':...
#
#                                             document Word Positions
# 0  alt atheism faq atheist resources archive name...         161442
# 1  spring records the orioles pitching staff agai...         119407
# 2  re sex education in article mar athos rutgers ...         216581
# 3  wanted bus card for logitech mouse i ve acquir...         112583
# 4  re gun control was re we re mad as hell at the...         191723

# %%
# remove stop words
# dataInfoStopEdit = dataInfo.copy()
# for docType in dataInfoStopEdit["Type"]:
#     print(docType)
#     text = dataInfoStopEdit["document"][dataInfoStopEdit["Type"]==docType].tolist()[0]
#     dataInfoStopEdit["document"][dataInfoStopEdit["Type"]==docType] = ' '.join([word for word in text.split() if word not in cachedStopWords])

#     dataInfoStopEdit["Word Positions"][dataInfoStopEdit["Type"]==docType] = len(dataInfoStopEdit["document"][dataInfoStopEdit["Type"]==docType].tolist()[0].split())

# dataInfoStopEdit = wordCount(dataInfoStopEdit)

# # # save the thing
# # dataInfoStopEdit.to_csv("dataInfoStopEdit.csv", index=False, sep=",", header=True)
# # save_it_all(dataInfoStopEdit, "./dataInfoStopEdit.pkl")

dataInfoStopEdit.head()


vocabStopEdit = []
vocabStopEdit = set([word for word in vocabulary if word not in cachedStopWords])
len(vocabStopEdit)
#save_it_all(vocabStopEdit, "./vocabStemmingEdit.pkl")
len(vocabStopEdit)
# Out:
# 73560

# %%
# remove Stemming words

dataInfoStemmingEdit = dataInfo.copy()
for docType in dataInfoStemmingEdit["Type"]:
    print(docType)
    text = dataInfoStemmingEdit["document"][dataInfoStemmingEdit["Type"]==docType].tolist()[0]
    dataInfoStemmingEdit["document"][dataInfoStemmingEdit["Type"]==docType] = ' '.join([stemmer.stem(word) for word in text.split() ])

    dataInfoStemmingEdit["Word Positions"][dataInfoStemmingEdit["Type"]==docType] = len(dataInfoStemmingEdit["document"][dataInfoStemmingEdit["Type"]==docType].tolist()[0].split())

dataInfoStemmingEdit = wordCount(dataInfoStemmingEdit)

# # save the thing
# dataInfoStemmingEdit.to_csv("dataInfoStemmingEdit.csv", index=False, sep=",", header=True)
# save_it_all(dataInfoStemmingEdit, "./dataInfoStemmingEdit.pkl")
dataInfoStemmingEdit.head()

vocabStemmingEdit = []
vocabStemmingEdit = set([stemmer.stem(word) for word in vocabulary])
len(vocabStemmingEdit)
#save_it_all(vocabStemmingEdit, "./vocabStemmingEdit.pkl")

# %%
# remove stop and stemming words
dataInfoStopStemmingEdit = dataInfo.copy()

vocabStopStemmingEdit = []
vocabStopStemmingEdit = [stemmer.stem(word) for word in vocabulary if word not in cachedStopWords]

for docType in dataInfoStopStemmingEdit["Type"]:
    print(docType)
    text = dataInfoStopStemmingEdit["document"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0]
    dataInfoStopStemmingEdit["document"][dataInfoStopStemmingEdit["Type"]==docType] = ' '.join([stemmer.stem(word) for word in text.split() if word not in cachedStopWords])

    dataInfoStopStemmingEdit["Word Positions"][dataInfoStopStemmingEdit["Type"]==docType] = len(dataInfoStopStemmingEdit["document"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0].split())

dataInfoStopStemmingEdit = wordCount(dataInfoStopStemmingEdit, vocabStopStemmingEdit)

# save the thing
dataInfoStopStemmingEdit.to_csv("dataInfoStopStemmingEdit.csv", index=False, sep=",", header=True)
save_it_all(dataInfoStopStemmingEdit, "./dataInfoStopStemmingEdit.pkl")
dataInfoStopStemmingEdit.head()
len(set(vocabStopStemmingEdit))
save_it_all(vocabStopStemmingEdit, "./vocabStopStemmingEdit.pkl")
#
dataInfoStopStemmingEdit.head()
# Out:
# atheism
# baseball
# christianity
# pc
# guns
# mideastpolitics
# mac
# electronics
# forsale
# autos
# graphics
# religion
# xwindows
# hockey
# motorcycles
# mswindows
# cryptology
# space
# politics
# medicine
#            Type  Count Probablility  \
# 0       atheism    480    0.0425042
# 1      baseball    597    0.0528646
# 2  christianity    598    0.0529532
# 3            pc    590    0.0522448
# 4          guns    545      0.04826
#
#                                            wordCount  \
# 0  {'alt': 89, 'atheism': 301, 'faq': 73, 'atheis...
# 1  {'alt': 1, 'atheism': {'count': 0, 'probabilit...
# 2  {'alt': 14, 'atheism': 17, 'faq': 17, 'atheist...
# 3  {'alt': 10, 'atheism': {'count': 0, 'probabili...
# 4  {'alt': 11, 'atheism': {'count': 0, 'probabili...
#
#                                             document Word Positions
# 0  alt atheism faq atheist resourc archiv name at...          81587
# 1  spring record oriol pitch staff fine exhibit s...          66918
# 2  sex educ articl mar atho rutger edu swansond n...         105784
# 3  want bus card logitech mous acquir old logitec...          64961
# 4  gun control mad hell tv news hambidg bms com w...         103158

# %%
# word probablity 
# work count probability for dataInfoStopStemmingEdit
dataInfoStopStemmingEdit = load_objects("dataInfoStopStemmingEdit.pkl")
for docType in dataInfoStopStemmingEdit["Type"]:
    print(docType)
    wordCountDict = list(set(dataInfoStopStemmingEdit["document"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0].split()))
    for key in wordCountDict:
        nk = dataInfoStopStemmingEdit["wordCount"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0][key]
        n = dataInfoStopStemmingEdit["Word Positions"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0]
        probability = math.log(nk + 1) - math.log(n + len(vocabStopStemmingEdit))
        newDict = {"count": nk, "probability":probability}
        dataInfoStopStemmingEdit["wordCount"][dataInfoStopStemmingEdit["Type"]==docType].tolist()[0][key] = newDict
# Out:
# atheism
# baseball
# christianity
# pc
# guns
# mideastpolitics
# mac
# electronics
# forsale
# autos
# graphics
# religion
# xwindows
# hockey
# motorcycles
# mswindows
# cryptology
# space
# politics
# medicine

# %%
dataInfoStopStemmingEdit.head()
save_it_all(dataInfoStopStemmingEdit, "./dataInfoStopStemmingEdit.pkl")

# %%
dataInfoStopStemmingEdit["wordCount"][dataInfoStopStemmingEdit["Type"]==docType].tolist()
# Out:
# [{'alt': {'count': 22, 'probability': -8.908035970414664},
#   'atheism': {'count': 0, 'probability': -12.043530186343814},
#   'faq': {'count': 37, 'probability': -8.405944026617428},
#   'atheist': {'count': 0, 'probability': -12.043530186343814},
#   'resourc': {'count': 18, 'probability': -9.099091207177374},
#   'archiv': {'count': 18, 'probability': -9.099091207177374},
#   'name': {'count': 60, 'probability': -7.932656322170502},
#   'last': {'count': 76, 'probability': -7.69972476449013},
#   'modifi': {'count': 5, 'probability': -10.25177071711576},
#   'decemb': {'count': 9, 'probability': -9.740945093349769},
#   'version': {'count': 30, 'probability': -8.609542981858667},
#   'address': {'count': 43, 'probability': -8.259340552425552},
#   'organ': {'count': 89, 'probability': -7.543720516013549},
#   'usa': {'count': 15, 'probability': -9.270941464104032},
#   'freedom': {'count': 2, 'probability': -10.944917897675705},
#   'religion': {'count': 0, 'probability': -12.043530186343814},
#   'foundat': {'count': 18, 'probability': -9.099091207177374},
#   'darwin': {'count': 3, 'probability': -10.657235825223923},
#   'fish': {'count': 3, 'probability': -10.657235825223923},
#   'bumper': {'count': 0, 'probability': -12.043530186343814},
#   'sticker': {'count': 1, 'probability': -11.350383005783868},
#   'assort': {'count': 0, 'probability': -12.043530186343814},
#   'paraphernalia': {'count': 0, 'probability': -12.043530186343814},
#   'avail': {'count': 102, 'probability': -7.408801198114178},
#   'us': {'count': 135, 'probability': -7.130875300607761},
#   'write': {'count': 468, 'probability': -5.892927417897535},
#   'ffrf': {'count': 0, 'probability': -12.043530186343814},
#   'p': {'count': 97, 'probability': -7.4585627076732415},
#   'box': {'count': 27, 'probability': -8.71132567616861},
#   'madison': {'count': 3, 'probability': -10.657235825223923},
#   'wi': {'count': 12, 'probability': -9.478580828882277},
#   'telephon': {'count': 12, 'probability': -9.478580828882277},
#   'evolut': {'count': 5, 'probability': -10.25177071711576},
#   'design': {'count': 42, 'probability': -8.282330070650252},
#   'sell': {'count': 12, 'probability': -9.478580828882277},
#   'symbol': {'count': 1, 'probability': -11.350383005783868},
#   'like': {'count': 344, 'probability': -6.199985769312454},
#   'one': {'count': 586, 'probability': -5.668505366515717},
#   'christian': {'count': 1, 'probability': -11.350383005783868},
#   'stick': {'count': 5, 'probability': -10.25177071711576},
#   'car': {'count': 3, 'probability': -10.657235825223923},
#   'feet': {'count': 12, 'probability': -9.478580828882277},
#   'word': {'count': 47, 'probability': -8.172329175435923},
#   'written': {'count': 15, 'probability': -9.270941464104032},
#   'insid': {'count': 9, 'probability': -9.740945093349769},
#   'delux': {'count': 0, 'probability': -12.043530186343814},
#   'mould': {'count': 1, 'probability': -11.350383005783868},
#   'plastic': {'count': 4, 'probability': -10.434092273909714},
#   'postpaid': {'count': 0, 'probability': -12.043530186343814},
#   'laurel': {'count': 0, 'probability': -12.043530186343814},
#   'canyon': {'count': 0, 'probability': -12.043530186343814},
#   'north': {'count': 23, 'probability': -8.865476355995868},
#   'hollywood': {'count': 0, 'probability': -12.043530186343814},
#   'ca': {'count': 110, 'probability': -7.33399998503148},
#   'peopl': {'count': 323, 'probability': -6.262786670551485},
#   'san': {'count': 22, 'probability': -8.908035970414664},
#   'francisco': {'count': 8, 'probability': -9.846305609007594},
#   'bay': {'count': 1, 'probability': -11.350383005783868},
#   'area': {'count': 78, 'probability': -7.674082333876792},
#   'get': {'count': 380, 'probability': -6.100730811217113},
#   'lynn': {'count': 5, 'probability': -10.25177071711576},
#   'gold': {'count': 1, 'probability': -11.350383005783868},
#   'tri': {'count': 151, 'probability': -7.019649665497537},
#   'mail': {'count': 111, 'probability': -7.32503131504872},
#   'figmo': {'count': 0, 'probability': -12.043530186343814},
#   'netcom': {'count': 50, 'probability': -8.111704553619488},
#   'com': {'count': 570, 'probability': -5.696140976687803},
#   'net': {'count': 47, 'probability': -8.172329175435923},
#   'go': {'count': 164, 'probability': -6.9375847124432335},
#   'direct': {'count': 63, 'probability': -7.884647102984142},
#   'price': {'count': 40, 'probability': -8.329958119639507},
#   'per': {'count': 66, 'probability': -7.838837566952848},
#   'american': {'count': 45, 'probability': -8.214888789854719},
#   'press': {'count': 21, 'probability': -8.952487732985498},
#   'aap': {'count': 0, 'probability': -12.043530186343814},
#   'publish': {'count': 53, 'probability': -8.05454613977954},
#   'various': {'count': 35, 'probability': -8.460011247887703},
#   'book': {'count': 58, 'probability': -7.965992742438094},
#   'critiqu': {'count': 4, 'probability': -10.434092273909714},
#   'bibl': {'count': 0, 'probability': -12.043530186343814},
#   'list': {'count': 50, 'probability': -8.111704553619488},
#   'biblic': {'count': 0, 'probability': -12.043530186343814},
#   'contradict': {'count': 6, 'probability': -10.0976200372885},
#   'handbook': {'count': 4, 'probability': -10.434092273909714},
#   'w': {'count': 53, 'probability': -8.05454613977954},
#   'ball': {'count': 8, 'probability': -9.846305609007594},
#   'g': {'count': 66, 'probability': -7.838837566952848},
#   'foot': {'count': 9, 'probability': -9.740945093349769},
#   'pp': {'count': 4, 'probability': -10.434092273909714},
#   'isbn': {'count': 7, 'probability': -9.964088644663978},
#   'nd': {'count': 5, 'probability': -10.25177071711576},
#   'edit': {'count': 17, 'probability': -9.15315842844765},
#   'absurd': {'count': 26, 'probability': -8.747693320339485},
#   'atroc': {'count': 0, 'probability': -12.043530186343814},
#   'immor': {'count': 0, 'probability': -12.043530186343814},
#   'contain': {'count': 69, 'probability': -7.795034944294454},
#   'base': {'count': 62, 'probability': -7.900395459952281},
#   'king': {'count': 15, 'probability': -9.270941464104032},
#   'jame': {'count': 13, 'probability': -9.404472856728555},
#   'austin': {'count': 4, 'probability': -10.434092273909714},
#   'tx': {'count': 9, 'probability': -9.740945093349769},
#   'cameron': {'count': 1, 'probability': -11.350383005783868},
#   'road': {'count': 11, 'probability': -9.558623536555814},
#   'fax': {'count': 44, 'probability': -8.236867696573494},
#   'prometheus': {'count': 0, 'probability': -12.043530186343814},
#   'includ': {'count': 111, 'probability': -7.32503131504872},
#   'haught': {'count': 0, 'probability': -12.043530186343814},
#   'holi': {'count': 0, 'probability': -12.043530186343814},
#   'horror': {'count': 0, 'probability': -12.043530186343814},
#   'see': {'count': 187, 'probability': -6.8070882235138646},
#   'east': {'count': 12, 'probability': -9.478580828882277},
#   'amherst': {'count': 2, 'probability': -10.944917897675705},
#   'street': {'count': 22, 'probability': -8.908035970414664},
#   'buffalo': {'count': 6, 'probability': -10.0976200372885},
#   'new': {'count': 211, 'probability': -6.6869439116718015},
#   'york': {'count': 33, 'probability': -8.517169661727653},
#   'altern': {'count': 47, 'probability': -8.172329175435923},
#   'may': {'count': 209, 'probability': -6.696422655626345},
#   'newer': {'count': 3, 'probability': -10.657235825223923},
#   'older': {'count': 10, 'probability': -9.645634913545443},
#   'glenn': {'count': 4, 'probability': -10.434092273909714},
#   'drive': {'count': 20, 'probability': -8.999007748620391},
#   'ny': {'count': 21, 'probability': -8.952487732985498},
#   'african': {'count': 0, 'probability': -12.043530186343814},
#   'human': {'count': 118, 'probability': -7.264406693232284},
#   'promot': {'count': 26, 'probability': -8.747693320339485},
#   'black': {'count': 17, 'probability': -9.15315842844765},
#   'secular': {'count': 0, 'probability': -12.043530186343814},
#   'uncov': {'count': 1, 'probability': -11.350383005783868},
#   'histori': {'count': 30, 'probability': -8.609542981858667},
#   'freethought': {'count': 0, 'probability': -12.043530186343814},
#   'quarter': {'count': 0, 'probability': -12.043530186343814},
#   'newslett': {'count': 73, 'probability': -7.739465093139644},
#   'aah': {'count': 0, 'probability': -12.043530186343814},
#   'examin': {'count': 21, 'probability': -8.952487732985498},
#   'norm': {'count': 0, 'probability': -12.043530186343814},
#   'r': {'count': 51, 'probability': -8.092286467762387},
#   'allen': {'count': 3, 'probability': -10.657235825223923},
#   'jr': {'count': 7, 'probability': -9.964088644663978},
#   'unit': {'count': 61, 'probability': -7.916395801298722},
#   'kingdom': {'count': 3, 'probability': -10.657235825223923},
#   'rationalist': {'count': 0, 'probability': -12.043530186343814},
#   'associ': {'count': 69, 'probability': -7.795034944294454},
#   'nation': {'count': 82, 'probability': -7.6246895785472155},
#   'societi': {'count': 9, 'probability': -9.740945093349769},
#   'islington': {'count': 0, 'probability': -12.043530186343814},
#   'high': {'count': 119, 'probability': -7.256038443561768},
#   'holloway': {'count': 6, 'probability': -10.0976200372885},
#   'london': {'count': 1, 'probability': -11.350383005783868},
#   'n': {'count': 147, 'probability': -7.046317912579699},
#   'ew': {'count': 0, 'probability': -12.043530186343814},
#   'nl': {'count': 7, 'probability': -9.964088644663978},
#   'british': {'count': 6, 'probability': -10.0976200372885},
#   'humanist': {'count': 0, 'probability': -12.043530186343814},
#   'south': {'count': 12, 'probability': -9.478580828882277},
#   'place': {'count': 71, 'probability': -7.7668640673277585},
#   'ethic': {'count': 14, 'probability': -9.335479985241603},
#   'lamb': {'count': 2, 'probability': -10.944917897675705},
#   'conduit': {'count': 0, 'probability': -12.043530186343814},
#   'passag': {'count': 3, 'probability': -10.657235825223923},
#   'conway': {'count': 0, 'probability': -12.043530186343814},
#   'hall': {'count': 2, 'probability': -10.944917897675705},
#   'wc': {'count': 1, 'probability': -11.350383005783868},
#   'rh': {'count': 2, 'probability': -10.944917897675705},
#   'red': {'count': 20, 'probability': -8.999007748620391},
#   'lion': {'count': 1, 'probability': -11.350383005783868},
#   'squar': {'count': 2, 'probability': -10.944917897675705},
#   'rl': {'count': 1, 'probability': -11.350383005783868},
#   'freethink': {'count': 0, 'probability': -12.043530186343814},
#   'month': {'count': 87, 'probability': -7.566193371865607},
#   'magazin': {'count': 7, 'probability': -9.964088644663978},
#   'found': {'count': 93, 'probability': -7.50023540407381},
#   'germani': {'count': 2, 'probability': -10.944917897675705},
#   'ibka': {'count': 0, 'probability': -12.043530186343814},
#   'e': {'count': 186, 'probability': -6.812421569489227},
#   'v': {'count': 40, 'probability': -8.329958119639507},
#   'international': {'count': 0, 'probability': -12.043530186343814},
#   'bund': {'count': 0, 'probability': -12.043530186343814},
#   'der': {'count': 0, 'probability': -12.043530186343814},
#   'konfessionslosen': {'count': 0, 'probability': -12.043530186343814},
#   'und': {'count': 0, 'probability': -12.043530186343814},
#   'atheisten': {'count': 0, 'probability': -12.043530186343814},
#   'postfach': {'count': 0, 'probability': -12.043530186343814},
#   'berlin': {'count': 1, 'probability': -11.350383005783868},
#   'journal': {'count': 30, 'probability': -8.609542981858667},
#   'miz': {'count': 0, 'probability': -12.043530186343814},
#   'materialien': {'count': 0, 'probability': -12.043530186343814},
#   'informationen': {'count': 0, 'probability': -12.043530186343814},
#   'zur': {'count': 0, 'probability': -12.043530186343814},
#   'zeit': {'count': 0, 'probability': -12.043530186343814},
#   'politisch': {'count': 0, 'probability': -12.043530186343814},
#   'konfessionslosesn': {'count': 0, 'probability': -12.043530186343814},
#   'hrsg': {'count': 0, 'probability': -12.043530186343814},
#   'vertrieb': {'count': 0, 'probability': -12.043530186343814},
#   'ibdk': {'count': 0, 'probability': -12.043530186343814},
#   'b': {'count': 109, 'probability': -7.343049820551397},
#   'ucherdienst': {'count': 0, 'probability': -12.043530186343814},
#   'hannov': {'count': 0, 'probability': -12.043530186343814},
#   'fiction': {'count': 6, 'probability': -10.0976200372885},
#   'thoma': {'count': 10, 'probability': -9.645634913545443},
#   'disch': {'count': 0, 'probability': -12.043530186343814},
#   'santa': {'count': 2, 'probability': -10.944917897675705},
#   'claus': {'count': 0, 'probability': -12.043530186343814},
#   'compromis': {'count': 14, 'probability': -9.335479985241603},
#   'short': {'count': 45, 'probability': -8.214888789854719},
#   'stori': {'count': 32, 'probability': -8.547022624877334},
#   'ultim': {'count': 3, 'probability': -10.657235825223923},
#   'proof': {'count': 10, 'probability': -9.645634913545443},
#   'exist': {'count': 52, 'probability': -8.073238272791691},
#   'charact': {'count': 3, 'probability': -10.657235825223923},
#   'event': {'count': 13, 'probability': -9.404472856728555},
#   'fictiti': {'count': 0, 'probability': -12.043530186343814},
#   'similar': {'count': 66, 'probability': -7.838837566952848},
#   'live': {'count': 73, 'probability': -7.739465093139644},
#   'dead': {'count': 9, 'probability': -9.740945093349769},
#   'god': {'count': 9, 'probability': -9.740945093349769},
#   'uh': {'count': 1, 'probability': -11.350383005783868},
#   'well': {'count': 185, 'probability': -6.817783512630612},
#   'walter': {'count': 12, 'probability': -9.478580828882277},
#   'miller': {'count': 8, 'probability': -9.846305609007594},
#   'canticl': {'count': 0, 'probability': -12.043530186343814},
#   'leibowitz': {'count': 0, 'probability': -12.043530186343814},
#   'gem': {'count': 0, 'probability': -12.043530186343814},
#   'post': {'count': 162, 'probability': -6.9497799855370515},
#   'atom': {'count': 0, 'probability': -12.043530186343814},
#   'doomsday': {'count': 0, 'probability': -12.043530186343814},
#   'novel': {'count': 4, 'probability': -10.434092273909714},
#   'monk': {'count': 0, 'probability': -12.043530186343814},
#   'spent': {'count': 11, 'probability': -9.558623536555814},
#   'copi': {'count': 16, 'probability': -9.210316842287597},
#   'blueprint': {'count': 0, 'probability': -12.043530186343814},
#   'saint': {'count': 0, 'probability': -12.043530186343814},
#   'fill': {'count': 6, 'probability': -10.0976200372885},
#   'sheet': {'count': 7, 'probability': -9.964088644663978},
#   'paper': {'count': 36, 'probability': -8.43261227369959},
#   'ink': {'count': 0, 'probability': -12.043530186343814},
#   'leav': {'count': 27, 'probability': -8.71132567616861},
#   'white': {'count': 21, 'probability': -8.952487732985498},
#   'line': {'count': 45, 'probability': -8.214888789854719},
#   'letter': {'count': 24, 'probability': -8.824654361475613},
#   'edgar': {'count': 0, 'probability': -12.043530186343814},
#   'pangborn': {'count': 0, 'probability': -12.043530186343814},
#   'davi': {'count': 3, 'probability': -10.657235825223923},
#   'set': {'count': 54, 'probability': -8.036197001111343},
#   'cleric': {'count': 0, 'probability': -12.043530186343814},
#   'state': {'count': 125, 'probability': -7.207248279392336},
#   'church': {'count': 0, 'probability': -12.043530186343814},
#   'exampl': {'count': 73, 'probability': -7.739465093139644},
#   'forbid': {'count': 0, 'probability': -12.043530186343814},
#   'anyon': {'count': 151, 'probability': -7.019649665497537},
#   'produc': {'count': 59, 'probability': -7.949185624121713},
#   'describ': {'count': 46, 'probability': -8.193382584633756},
#   'use': {'count': 539, 'probability': -5.751961046785493},
#   'substanc': {'count': 47, 'probability': -8.172329175435923},
#   'philip': {'count': 3, 'probability': -10.657235825223923},
#   'k': {'count': 58, 'probability': -7.965992742438094},
#   'dick': {'count': 7, 'probability': -9.964088644663978},
#   'wrote': {'count': 36, 'probability': -8.43261227369959},
#   'mani': {'count': 209, 'probability': -6.696422655626345},
#   'philosoph': {'count': 15, 'probability': -9.270941464104032},
#   'thought': {'count': 66, 'probability': -7.838837566952848},
#   'provok': {'count': 2, 'probability': -10.944917897675705},
#   'bizarr': {'count': 10, 'probability': -9.645634913545443},
#   'time': {'count': 307, 'probability': -6.31343040337024},
#   'approach': {'count': 44, 'probability': -8.236867696573494},
#   'main': {'count': 32, 'probability': -8.547022624877334},
#   'sf': {'count': 8, 'probability': -9.846305609007594},
#   'truth': {'count': 14, 'probability': -9.335479985241603},
#   'rather': {'count': 57, 'probability': -7.983087175797395},
#   'technolog': {'count': 58, 'probability': -7.965992742438094},
#   'although': {'count': 49, 'probability': -8.131507180915667},
#   'often': {'count': 70, 'probability': -7.780850309302498},
#   'believ': {'count': 109, 'probability': -7.343049820551397},
#   'met': {'count': 7, 'probability': -9.964088644663978},
#   'sort': {'count': 56, 'probability': -8.000478918509263},
#   'remain': {'count': 17, 'probability': -9.15315842844765},
#   'sceptic': {'count': 2, 'probability': -10.944917897675705},
#   'amongst': {'count': 0, 'probability': -12.043530186343814},
#   'follow': {'count': 76, 'probability': -7.69972476449013},
#   'relev': {'count': 19, 'probability': -9.047797912789823},
#   'galact': {'count': 0, 'probability': -12.043530186343814},
#   'pot': {'count': 4, 'probability': -10.434092273909714},
#   'healer': {'count': 4, 'probability': -10.434092273909714},
#   'fallibl': {'count': 0, 'probability': -12.043530186343814},
#   'alien': {'count': 7, 'probability': -9.964088644663978},
#   'deiti': {'count': 0, 'probability': -12.043530186343814},
#   'summon': {'count': 0, 'probability': -12.043530186343814},
#   'group': {'count': 105, 'probability': -7.380091092231747},
#   'earth': {'count': 6, 'probability': -10.0976200372885},
#   'craftsmen': {'count': 0, 'probability': -12.043530186343814},
#   'women': {'count': 39, 'probability': -8.354650732229878},
#   'remot': {'count': 1, 'probability': -11.350383005783868},
#   'planet': {'count': 1, 'probability': -11.350383005783868},
#   'rais': {'count': 11, 'probability': -9.558623536555814},
#   'giant': {'count': 2, 'probability': -10.944917897675705},
#   'cathedr': {'count': 0, 'probability': -12.043530186343814},
#   'beneath': {'count': 0, 'probability': -12.043530186343814},
#   'ocean': {'count': 0, 'probability': -12.043530186343814},
#   'begin': {'count': 31, 'probability': -8.577794283544087},
#   'demand': {'count': 5, 'probability': -10.25177071711576},
#   'faith': {'count': 2, 'probability': -10.944917897675705},
#   'earther': {'count': 0, 'probability': -12.043530186343814},
#   'joe': {'count': 2, 'probability': -10.944917897675705},
#   'fernwright': {'count': 0, 'probability': -12.043530186343814},
#   'unabl': {'count': 10, 'probability': -9.645634913545443},
#   'compli': {'count': 0, 'probability': -12.043530186343814},
#   'polish': {'count': 6, 'probability': -10.0976200372885},
#   'iron': {'count': 6, 'probability': -10.0976200372885},
#   'amus': {'count': 5, 'probability': -10.25177071711576},
#   'maze': {'count': 0, 'probability': -12.043530186343814},
#   'death': {'count': 14, 'probability': -9.335479985241603},
#   'noteworthi': {'count': 1, 'probability': -11.350383005783868},
#   'descript': {'count': 29, 'probability': -8.642332804681658},
#   'vali': {'count': 0, 'probability': -12.043530186343814},
#   'schizophren': {'count': 0, 'probability': -12.043530186343814},
#   'hero': {'count': 0, 'probability': -12.043530186343814},
#   'search': {'count': 20, 'probability': -8.999007748620391},
#   'hidden': {'count': 6, 'probability': -10.0976200372885},
#   'mysteri': {'count': 6, 'probability': -10.0976200372885},
#   'gnostic': {'count': 0, 'probability': -12.043530186343814},
#   'realiti': {'count': 9, 'probability': -9.740945093349769},
#   'fire': {'count': 19, 'probability': -9.047797912789823},
#   'brain': {'count': 75, 'probability': -7.712796846057483},
#   'pink': {'count': 3, 'probability': -10.657235825223923},
#   'laser': {'count': 21, 'probability': -8.952487732985498},
#   'beam': {'count': 0, 'probability': -12.043530186343814},
#   'unknown': {'count': 14, 'probability': -9.335479985241603},
#   'possibl': {'count': 109, 'probability': -7.343049820551397},
#   'divin': {'count': 1, 'probability': -11.350383005783868},
#   'origin': {'count': 37, 'probability': -8.405944026617428},
#   'accompani': {'count': 4, 'probability': -10.434092273909714},
#   'dogmat': {'count': 0, 'probability': -12.043530186343814},
#   'dismiss': {'count': 1, 'probability': -11.350383005783868},
#   'friend': {'count': 72, 'probability': -7.753070745195423},
#   'odd': {'count': 13, 'probability': -9.404472856728555},
#   'invas': {'count': 6, 'probability': -10.0976200372885},
#   'invad': {'count': 0, 'probability': -12.043530186343814},
#   'make': {'count': 218, 'probability': -6.654458456527313},
#   'young': {'count': 30, 'probability': -8.609542981858667},
#   'woman': {'count': 10, 'probability': -9.645634913545443},
#   'pregnant': {'count': 8, 'probability': -9.846305609007594},
#   'return': {'count': 23, 'probability': -8.865476355995868},
#   'anoth': {'count': 80, 'probability': -7.649081031671375},
#   'star': {'count': 6, 'probability': -10.0976200372885},
#   'system': {'count': 176, 'probability': -6.867380453769985},
#   'unfortun': {'count': 27, 'probability': -8.71132567616861},
#   'termin': {'count': 17, 'probability': -9.15315842844765},
#   'ill': {'count': 72, 'probability': -7.753070745195423},
#   'must': {'count': 88, 'probability': -7.554893816611674},
#   'assist': {'count': 22, 'probability': -8.908035970414664},
#   'man': {'count': 15, 'probability': -9.270941464104032},
#   'whose': {'count': 20, 'probability': -8.999007748620391},
#   'wire': {'count': 1, 'probability': -11.350383005783868},
#   'hour': {'count': 52, 'probability': -8.073238272791691},
#   'easi': {'count': 23, 'probability': -8.865476355995868},
#   'listen': {'count': 12, 'probability': -9.478580828882277},
#   'music': {'count': 2, 'probability': -10.944917897675705},
#   'margaret': {'count': 2, 'probability': -10.944917897675705},
#   'atwood': {'count': 0, 'probability': -12.043530186343814},
#   'handmaid': {'count': 0, 'probability': -12.043530186343814},
#   'tale': {'count': 1, 'probability': -11.350383005783868},
#   'premis': {'count': 0, 'probability': -12.043530186343814},
#   'congress': {'count': 8, 'probability': -9.846305609007594},
#   'assassin': {'count': 0, 'probability': -12.043530186343814},
#   'fundamentalist': {'count': 0, 'probability': -12.043530186343814},
#   'quick': {'count': 24, 'probability': -8.824654361475613},
#   'take': {'count': 217, 'probability': -6.659035123554725},
#   'charg': {'count': 18, 'probability': -9.099091207177374},
#   'right': {'count': 113, 'probability': -7.307331737949318},
#   'diari': {'count': 1, 'probability': -11.350383005783868},
#   'life': {'count': 52, 'probability': -8.073238272791691},
#   'theocraci': {'count': 0, 'probability': -12.043530186343814},
#   'properti': {'count': 8, 'probability': -9.846305609007594},
#   'revok': {'count': 0, 'probability': -12.043530186343814},
#   'bank': {'count': 135, 'probability': -7.130875300607761},
#   'account': {'count': 11, 'probability': -9.558623536555814},
#   'close': {'count': 34, 'probability': -8.4881821248544},
#   'sin': {'count': 0, 'probability': -12.043530186343814},
#   'luxuri': {'count': 0, 'probability': -12.043530186343814},
#   'outlaw': {'count': 4, 'probability': -10.434092273909714},
#   'radio': {'count': 17, 'probability': -9.15315842844765},
#   'read': {'count': 142, 'probability': -7.080685556083907},
#   'crime': {'count': 2, 'probability': -10.944917897675705},
#   'punish': {'count': 2, 'probability': -10.944917897675705},
#   'retroact': {'count': 0, 'probability': -12.043530186343814},
#   'doctor': {'count': 254, 'probability': -6.502266641185388},
#   'perform': {'count': 32, 'probability': -8.547022624877334},
#   'legal': {'count': 16, 'probability': -9.210316842287597},
#   'abort': {'count': 1, 'probability': -11.350383005783868},
#   'old': {'count': 73, 'probability': -7.739465093139644},
#   'world': {'count': 77, 'probability': -7.686821359654222},
#   'hunt': {'count': 4, 'probability': -10.434092273909714},
#   'hang': {'count': 1, 'probability': -11.350383005783868},
#   'style': {'count': 6, 'probability': -10.0976200372885},
#   'difficult': {'count': 16, 'probability': -9.210316842287597},
#   'first': {'count': 142, 'probability': -7.080685556083907},
#   'grow': {'count': 26, 'probability': -8.747693320339485},
#   'chill': {'count': 0, 'probability': -12.043530186343814},
#   'goe': {'count': 17, 'probability': -9.15315842844765},
#   'author': {'count': 30, 'probability': -8.609542981858667},
#   'somewhat': {'count': 18, 'probability': -9.099091207177374},
#   'dull': {'count': 4, 'probability': -10.434092273909714},
#   'rambl': {'count': 0, 'probability': -12.043530186343814},
#   'work': {'count': 240, 'probability': -6.558733252853159},
#   'critic': {'count': 24, 'probability': -8.824654361475613},
#   'howev': {'count': 98, 'probability': -7.448410336209224},
#   'probabl': {'count': 100, 'probability': -7.428409669502554},
#   'worth': {'count': 23, 'probability': -8.865476355995868},
#   'know': {'count': 317, 'probability': -6.281478803563637},
#   'fuss': {'count': 0, 'probability': -12.043530186343814},
#   'differ': {'count': 139, 'probability': -7.10188776373451},
#   'sure': {'count': 117, 'probability': -7.272845561878149},
#   'true': {'count': 55, 'probability': -8.018178495608664},
#   'non': {'count': 87, 'probability': -7.566193371865607},
#   'peter': {'count': 14, 'probability': -9.335479985241603},
#   'de': {'count': 10, 'probability': -9.645634913545443},
#   'rosa': {'count': 0, 'probability': -12.043530186343814},
#   'vicar': {'count': 0, 'probability': -12.043530186343814},
#   'christ': {'count': 0, 'probability': -12.043530186343814},
#   'bantam': {'count': 0, 'probability': -12.043530186343814},
#   'seem': {'count': 161, 'probability': -6.95593385111143},
#   'even': {'count': 187, 'probability': -6.8070882235138646},
#   'cathol': {'count': 0, 'probability': -12.043530186343814},
#   'enlight': {'count': 1, 'probability': -11.350383005783868},
#   'papal': {'count': 0, 'probability': -12.043530186343814},
#   'adulteri': {'count': 0, 'probability': -12.043530186343814},
#   'fallaci': {'count': 0, 'probability': -12.043530186343814},
#   'etc': {'count': 106, 'probability': -7.370701351881908},
#   'german': {'count': 0, 'probability': -12.043530186343814},
#   'translat': {'count': 5, 'probability': -10.25177071711576},
#   'gott': {'count': 0, 'probability': -12.043530186343814},
#   'erst': {'count': 0, 'probability': -12.043530186343814},
#   'diener': {'count': 0, 'probability': -12.043530186343814},
#   'die': {'count': 51, 'probability': -8.092286467762387},
#   'dunkl': {'count': 0, 'probability': -12.043530186343814},
#   'seit': {'count': 0, 'probability': -12.043530186343814},
#   'des': {'count': 0, 'probability': -12.043530186343814},
#   'papsttum': {'count': 0, 'probability': -12.043530186343814},
#   'droemer': {'count': 0, 'probability': -12.043530186343814},
#   'knaur': {'count': 0, 'probability': -12.043530186343814},
#   'michael': {'count': 38, 'probability': -8.379968540214168},
#   'martin': {'count': 14, 'probability': -9.335479985241603},
#   'justif': {'count': 2, 'probability': -10.944917897675705},
#   'templ': {'count': 2, 'probability': -10.944917897675705},
#   'univers': {'count': 156, 'probability': -6.987284380995506},
#   'philadelphia': {'count': 7, 'probability': -9.964088644663978},
#   'detail': {'count': 34, 'probability': -8.4881821248544},
#   'scholar': {'count': 1, 'probability': -11.350383005783868},
#   'outstand': {'count': 0, 'probability': -12.043530186343814},
#   'appendix': {'count': 1, 'probability': -11.350383005783868},
#   'defin': {'count': 19, 'probability': -9.047797912789823},
#   'terminolog': {'count': 0, 'probability': -12.043530186343814},
#   'usag': {'count': 5, 'probability': -10.25177071711576},
#   'necessarili': {'count': 19, 'probability': -9.047797912789823},
#   'tendenti': {'count': 0, 'probability': -12.043530186343814},
#   'argu': {'count': 19, 'probability': -9.047797912789823},
#   'negat': {'count': 21, 'probability': -8.952487732985498},
#   'belief': {'count': 10, 'probability': -9.645634913545443},
#   'also': {'count': 294, 'probability': -6.356554830003994},
#   'posit': {'count': 41, 'probability': -8.305860568060446},
#   'great': {'count': 97, 'probability': -7.4585627076732415},
#   'refut': {'count': 6, 'probability': -10.0976200372885},
#   'challeng': {'count': 9, 'probability': -9.740945093349769},
#   'argument': {'count': 23, 'probability': -8.865476355995868},
#   'particular': {'count': 51, 'probability': -8.092286467762387},
#   'attent': {'count': 19, 'probability': -9.047797912789823},
#   'paid': {'count': 10, 'probability': -9.645634913545443},
#   'contempori': {'count': 0, 'probability': -12.043530186343814},
#   'theist': {'count': 0, 'probability': -12.043530186343814},
#   'platinga': {'count': 0, 'probability': -12.043530186343814},
#   'swinburn': {'count': 0, 'probability': -12.043530186343814},
#   'page': {'count': 66, 'probability': -7.838837566952848},
#   'hardcov': {'count': 0, 'probability': -12.043530186343814},
#   'paperback': {'count': 0, 'probability': -12.043530186343814},
#   'case': {'count': 199, 'probability': -6.7452128197957775},
#   'comprehens': {'count': 23, 'probability': -8.865476355995868},
#   'consid': {'count': 62, 'probability': -7.900395459952281},
#   'best': {'count': 86, 'probability': -7.57762206768923},
#   'contemporari': {'count': 2, 'probability': -10.944917897675705},
#   'defenc': {'count': 0, 'probability': -12.043530186343814},
#   'demonstr': {'count': 14, 'probability': -9.335479985241603},
#   'unsupport': {'count': 0, 'probability': -12.043530186343814},
#   'incoher': {'count': 0, 'probability': -12.043530186343814},
#   'turner': {'count': 3, 'probability': -10.657235825223923},
#   'without': {'count': 122, 'probability': -7.231345830971397},
#   'creed': {'count': 0, 'probability': -12.043530186343814},
#   'john': {'count': 67, 'probability': -7.824022481167707},
#   'hopkin': {'count': 4, 'probability': -10.434092273909714},
#   'baltimor': {'count': 3, 'probability': -10.657235825223923},
#   'md': {'count': 41, 'probability': -8.305860568060446},
#   'subtitl': {'count': 0, 'probability': -12.043530186343814},
#   'unbelief': {'count': 0, 'probability': -12.043530186343814},
#   'america': {'count': 8, 'probability': -9.846305609007594},
#   'way': {'count': 147, 'probability': -7.046317912579699},
#   'whether': {'count': 69, 'probability': -7.795034944294454},
#   'agnost': {'count': 0, 'probability': -12.043530186343814},
#   'becam': {'count': 8, 'probability': -9.846305609007594},
#   'mainstream': {'count': 3, 'probability': -10.657235825223923},
#   'view': {'count': 35, 'probability': -8.460011247887703},
#   'focuss': {'count': 1, 'probability': -11.350383005783868},
#   'period': {'count': 26, 'probability': -8.747693320339485},
#   'franc': {'count': 1, 'probability': -11.350383005783868},
#   'britain': {'count': 8, 'probability': -9.846305609007594},
#   'emphasi': {'count': 1, 'probability': -11.350383005783868},
#   'england': {'count': 9, 'probability': -9.740945093349769},
#   'develop': {'count': 133, 'probability': -7.145690386392903},
#   'neither': {'count': 14, 'probability': -9.335479985241603},
#   'religi': {'count': 8, 'probability': -9.846305609007594},
#   'intellectu': {'count': 7, 'probability': -9.964088644663978},
#   'fate': {'count': 1, 'probability': -11.350383005783868},
#   'singl': {'count': 27, 'probability': -8.71132567616861},
#   'idea': {'count': 96, 'probability': -7.468819207840431},
#   'x': {'count': 62, 'probability': -7.900395459952281},
#   'georg': {'count': 15, 'probability': -9.270941464104032},
#   'seld': {'count': 0, 'probability': -12.043530186343814},
#   'editor': {'count': 11, 'probability': -9.558623536555814},
#   'ballantin': {'count': 0, 'probability': -12.043530186343814},
#   'dictionari': {'count': 15, 'probability': -9.270941464104032},
#   'quotat': {'count': 0, 'probability': -12.043530186343814},
#   'kind': {'count': 90, 'probability': -7.532670679826964},
#   'concentr': {'count': 14, 'probability': -9.335479985241603},
#   'statement': {'count': 8, 'probability': -9.846305609007594},
#   'explicit': {'count': 5, 'probability': -10.25177071711576},
#   'implicit': {'count': 3, 'probability': -10.657235825223923},
#   'present': {'count': 32, 'probability': -8.547022624877334},
#   'person': {'count': 150, 'probability': -7.0262503495288895},
#   'philosophi': {'count': 8, 'probability': -9.846305609007594},
#   'obscur': {'count': 2, 'probability': -10.944917897675705},
#   'suppress': {'count': 11, 'probability': -9.558623536555814},
#   'opinion': {'count': 74, 'probability': -7.726042072807504},
#   'popular': {'count': 13, 'probability': -9.404472856728555},
#   'observ': {'count': 48, 'probability': -8.151709888233187},
#   'trace': {'count': 8, 'probability': -9.846305609007594},
#   'express': {'count': 15, 'probability': -9.270941464104032},
#   'twist': {'count': 2, 'probability': -10.944917897675705},
#   'centuri': {'count': 7, 'probability': -9.964088644663978},
#   'quit': {'count': 81, 'probability': -7.63681093907956},
#   'number': {'count': 142, 'probability': -7.080685556083907},
#   'deriv': {'count': 10, 'probability': -9.645634913545443},
#   'cardiff': {'count': 0, 'probability': -12.043530186343814},
#   'men': {'count': 26, 'probability': -8.747693320339485},
#   'think': {'count': 264, 'probability': -6.463800360357592},
#   'noy': {'count': 0, 'probability': -12.043530186343814},
#   'richard': {'count': 34, 'probability': -8.4881821248544},
#   'revis': {'count': 5, 'probability': -10.25177071711576},
#   'clarendon': {'count': 0, 'probability': -12.043530186343814},
#   'oxford': {'count': 4, 'probability': -10.434092273909714},
#   'second': {'count': 40, 'probability': -8.329958119639507},
#   'volum': {'count': 60, 'probability': -7.932656322170502},
#   'trilog': {'count': 0, 'probability': -12.043530186343814},
#   'began': {'count': 13, 'probability': -9.404472856728555},
#   'coher': {'count': 2, 'probability': -10.944917897675705},
#   'theism': {'count': 0, 'probability': -12.043530186343814},
#   'conclud': {'count': 15, 'probability': -9.270941464104032},
#   'reason': {'count': 119, 'probability': -7.256038443561768},
#   'attempt': {'count': 12, 'probability': -9.478580828882277},
#   'construct': {'count': 17, 'probability': -9.15315842844765},
#   'seri': {'count': 8, 'probability': -9.846305609007594},
#   'induct': {'count': 5, 'probability': -10.25177071711576},
#   'reli': {'count': 5, 'probability': -10.25177071711576},
#   'upon': {'count': 19, 'probability': -9.047797912789823},
#   'imput': {'count': 1, 'probability': -11.350383005783868},
#   'late': {'count': 13, 'probability': -9.404472856728555},
#   'th': {'count': 36, 'probability': -8.43261227369959},
#   'western': {'count': 7, 'probability': -9.964088644663978},
#   'valu': {'count': 10, 'probability': -9.645634913545443},
#   'aesthet': {'count': 1, 'probability': -11.350383005783868},
#   'suppos': {'count': 29, 'probability': -8.642332804681658},
#   'simpl': {'count': 28, 'probability': -8.67623435635734},
#   'conceiv': {'count': 9, 'probability': -9.740945093349769},
#   'decis': {'count': 10, 'probability': -9.645634913545443},
#   'reject': {'count': 8, 'probability': -9.846305609007594},
#   'macki': {'count': 14, 'probability': -9.335479985241603},
#   'miracl': {'count': 15, 'probability': -9.270941464104032},
#   'rebut': {'count': 0, 'probability': -12.043530186343814},
#   'j': {'count': 78, 'probability': -7.674082333876792},
#   'l': {'count': 81, 'probability': -7.63681093907956},
#   'posthum': {'count': 0, 'probability': -12.043530186343814},
#   'review': {'count': 47, 'probability': -8.172329175435923},
#   'princip': {'count': 7, 'probability': -9.964088644663978},
#   'rang': {'count': 18, 'probability': -9.099091207177374},
#   'classic': {'count': 10, 'probability': -9.645634913545443},
#   'descart': {'count': 0, 'probability': -12.043530186343814},
#   'anselm': {'count': 0, 'probability': -12.043530186343814},
#   'berkeley': {'count': 58, 'probability': -7.965992742438094},
#   'hume': {'count': 1, 'probability': -11.350383005783868},
#   'et': {'count': 26, 'probability': -8.747693320339485},
#   'al': {'count': 21, 'probability': -8.952487732985498},
#   'moral': {'count': 6, 'probability': -10.0976200372885},
#   'newman': {'count': 0, 'probability': -12.043530186343814},
#   'kant': {'count': 0, 'probability': -12.043530186343814},
#   'sidgwick': {'count': 0, 'probability': -12.043530186343814},
#   'recent': {'count': 75, 'probability': -7.712796846057483},
#   'restat': {'count': 0, 'probability': -12.043530186343814},
#   'these': {'count': 0, 'probability': -12.043530186343814},
#   'plantinga': {'count': 0, 'probability': -12.043530186343814},
#   'push': {'count': 9, 'probability': -9.740945093349769},
#   'concept': {'count': 10, 'probability': -9.645634913545443},
#   'beyond': {'count': 20, 'probability': -8.999007748620391},
#   'realm': {'count': 0, 'probability': -12.043530186343814},
#   'ration': {'count': 41, 'probability': -8.305860568060446},
#   'kierkegaard': {'count': 0, 'probability': -12.043530186343814},
#   'kung': {'count': 0, 'probability': -12.043530186343814},
#   'replac': {'count': 9, 'probability': -9.740945093349769},
#   'leli': {'count': 0, 'probability': -12.043530186343814},
#   'axiarch': {'count': 0, 'probability': -12.043530186343814},
#   'delight': {'count': 1, 'probability': -11.350383005783868},
#   'less': {'count': 81, 'probability': -7.63681093907956},
#   'formalist': {'count': 0, 'probability': -12.043530186343814},
#   'better': {'count': 87, 'probability': -7.566193371865607},
#   'refresh': {'count': 1, 'probability': -11.350383005783868},
#   'compar': {'count': 35, 'probability': -8.460011247887703},
#   'hand': {'count': 69, 'probability': -7.795034944294454},
#   'wave': {'count': 9, 'probability': -9.740945093349769},
#   'illustr': {'count': 5, 'probability': -10.25177071711576},
#   'murder': {'count': 0, 'probability': -12.043530186343814},
#   'mad': {'count': 3, 'probability': -10.657235825223923},
#   'look': {'count': 126, 'probability': -7.199343099885223},
#   'persecut': {'count': 0, 'probability': -12.043530186343814},
#   'ancient': {'count': 5, 'probability': -10.25177071711576},
#   'day': {'count': 192, 'probability': -6.780839997438928},
#   'librari': {'count': 19, 'probability': -9.047797912789823},
#   'catalog': {'count': 7, 'probability': -9.964088644663978},
#   'card': {'count': 5, 'probability': -10.25177071711576},
#   'antholog': {'count': 0, 'probability': -12.043530186343814},
#   'gordon': {'count': 133, 'probability': -7.145690386392903},
#   'stein': {'count': 0, 'probability': -12.043530186343814},
#   'cover': {'count': 35, 'probability': -8.460011247887703},
#   'wide': {'count': 12, 'probability': -9.478580828882277},
#   'subject': {'count': 65, 'probability': -7.853875444317389},
#   'devil': {'count': 0, 'probability': -12.043530186343814},
#   'evil': {'count': 2, 'probability': -10.944917897675705},
#   'bibliographi': {'count': 2, 'probability': -10.944917897675705},
#   'edmund': {'count': 1, 'probability': -11.350383005783868},
#   'cohen': {'count': 4, 'probability': -10.434092273909714},
#   'mind': {'count': 48, 'probability': -8.151709888233187},
#   'studi': {'count': 229, 'probability': -6.605450877420618},
#   'becom': {'count': 67, 'probability': -7.824022481167707},
#   'effect': {'count': 244, 'probability': -6.542271975799086},
#   'small': {'count': 48, 'probability': -8.151709888233187},
#   'server': {'count': 11, 'probability': -9.558623536555814},
#   'manti': {'count': 0, 'probability': -12.043530186343814},
#   'co': {'count': 42, 'probability': -8.282330070650252},
#   'uk': {'count': 35, 'probability': -8.460011247887703},
#   'carri': {'count': 25, 'probability': -8.785433648322332},
#   'moder': {'count': 6, 'probability': -10.0976200372885},
#   'articl': {'count': 462, 'probability': -5.90580313225758},
#   'file': {'count': 26, 'probability': -8.747693320339485},
#   'inform': {'count': 198, 'probability': -6.7502253616193215},
#   'send': {'count': 38, 'probability': -8.379968540214168},
#   'say': {'count': 194, 'probability': -6.770530627780067},
#   'help': {'count': 195, 'probability': -6.765415527113297},
#   'index': {'count': 4, 'probability': -10.434092273909714},
#   'back': {'count': 145, 'probability': -7.059923564635477},
#   'repli': {'count': 44, 'probability': -8.236867696573494},
#   'mathew': {'count': 0, 'probability': -12.043530186343814},
#   'introduct': {'count': 6, 'probability': -10.0976200372885},
#   'april': {'count': 82, 'probability': -7.6246895785472155},
#   'pgp': {'count': 0, 'probability': -12.043530186343814},
#   'sign': {'count': 17, 'probability': -9.15315842844765},
#   'messag': {'count': 26, 'probability': -8.747693320339485},
#   'provid': {'count': 102, 'probability': -7.408801198114178},
#   'general': {'count': 110, 'probability': -7.33399998503148},
#   'whilst': {'count': 2, 'probability': -10.944917897675705},
#   'neutral': {'count': 4, 'probability': -10.434092273909714},
#   'regard': {'count': 29, 'probability': -8.642332804681658},
#   'contenti': {'count': 0, 'probability': -12.043530186343814},
#   'issu': {'count': 60, 'probability': -7.932656322170502},
#   'alway': {'count': 55, 'probability': -8.018178495608664},
#   'rememb': {'count': 51, 'probability': -8.092286467762387},
#   'document': {'count': 21, 'probability': -8.952487732985498},
#   'repres': {'count': 14, 'probability': -9.335479985241603},
#   'viewpoint': {'count': 3, 'probability': -10.657235825223923},
#   'would': {'count': 424, 'probability': -5.991441017419397},
#   'encourag': {'count': 18, 'probability': -9.099091207177374},
#   'draw': {'count': 1, 'probability': -11.350383005783868},
#   'conclus': {'count': 14, 'probability': -9.335479985241603},
#   'companion': {'count': 2, 'probability': -10.944917897675705},
#   'sens': {'count': 43, 'probability': -8.259340552425552},
#   'cohes': {'count': 0, 'probability': -12.043530186343814},
#   'progress': {'count': 25, 'probability': -8.785433648322332},
#   'imaginari': {'count': 2, 'probability': -10.944917897675705},
#   'convers': {'count': 7, 'probability': -9.964088644663978},
#   'question': {'count': 170, 'probability': -6.9018666298411535},
#   'ask': {'count': 79, 'probability': -7.661503551669933},
#   'crop': {'count': 0, 'probability': -12.043530186343814},
#   'repeat': {'count': 22, 'probability': -8.908035970414664},
#   'sinc': {'count': 143, 'probability': -7.073716886767813},
#   'newsgroup': {'count': 46, 'probability': -8.193382584633756},
#   'creat': {'count': 19, 'probability': -9.047797912789823},
#   'frequent': {'count': 38, 'probability': -8.379968540214168},
#   'answer': {'count': 45, 'probability': -8.214888789854719},
#   'pleas': {'count': 86, 'probability': -7.57762206768923},
#   'note': {'count': 45, 'probability': -8.214888789854719},
#   'arguabl': {'count': 4, 'probability': -10.434092273909714},
#   'slant': {'count': 0, 'probability': -12.043530186343814},
#   'toward': {'count': 28, 'probability': -8.67623435635734},
#   'pose': {'count': 5, 'probability': -10.25177071711576},
#   'reflect': {'count': 6, 'probability': -10.0976200372885},
#   'actual': {'count': 68, 'probability': -7.809423681746554},
#   'predomin': {'count': 6, 'probability': -10.0976200372885},
#   'proselyt': {'count': 0, 'probability': -12.043530186343814},
#   'talk': {'count': 47, 'probability': -8.172329175435923},
#   'primarili': {'count': 6, 'probability': -10.0976200372885},
#   'judaism': {'count': 0, 'probability': -12.043530186343814},
#   'islam': {'count': 0, 'probability': -12.043530186343814},
#   'involv': {'count': 72, 'probability': -7.753070745195423},
#   'superhuman': {'count': 0, 'probability': -12.043530186343814},
#   'much': {'count': 174, 'probability': -6.878744212420299},
#   'discuss': {'count': 55, 'probability': -8.018178495608664},
#   'appli': {'count': 52, 'probability': -8.073238272791691},
#   'character': {'count': 11, 'probability': -9.558623536555814},
#   'absenc': {'count': 3, 'probability': -10.657235825223923},
#   'former': {'count': 20, 'probability': -8.999007748620391},
#   'refer': {'count': 72, 'probability': -7.753070745195423},
#   'weak': {'count': 18, 'probability': -9.099091207177374},
#   'latter': {'count': 8, 'probability': -9.846305609007594},
#   'strong': {'count': 34, 'probability': -8.4881821248544},
#   'import': {'count': 61, 'probability': -7.916395801298722},
#   'two': {'count': 150, 'probability': -7.0262503495288895},
#   'disbelief': {'count': 0, 'probability': -12.043530186343814},
#   'fall': {'count': 19, 'probability': -9.047797912789823},
#   'trap': {'count': 3, 'probability': -10.657235825223923},
#   'assum': {'count': 25, 'probability': -8.785433648322332},
#   'other': {'count': 44, 'probability': -8.236867696573494},
#   'limit': {'count': 40, 'probability': -8.329958119639507},
#   'specif': {'count': 43, 'probability': -8.259340552425552},
#   'flat': {'count': 7, 'probability': -9.964088644663978},
#   'denial': {'count': 1, 'probability': -11.350383005783868},
#   'disbeliev': {'count': 0, 'probability': -12.043530186343814},
#   'thing': {'count': 179, 'probability': -6.850573335453603},
#   'definit': {'count': 42, 'probability': -8.282330070650252},
#   'proposit': {'count': 0, 'probability': -12.043530186343814},
#   'mean': {'count': 86, 'probability': -7.57762206768923},
#   'someth': {'count': 131, 'probability': -7.160728263757443},
#   'equival': {'count': 12, 'probability': -9.478580828882277},
#   'fals': {'count': 10, 'probability': -9.645634913545443},
#   'simpli': {'count': 28, 'probability': -8.67623435635734},
#   'bring': {'count': 22, 'probability': -8.908035970414664},
#   'agnostic': {'count': 0, 'probability': -12.043530186343814},
#   'term': {'count': 45, 'probability': -8.214888789854719},
#   'coin': {'count': 0, 'probability': -12.043530186343814},
#   'professor': {'count': 11, 'probability': -9.558623536555814},
#   'huxley': {'count': 3, 'probability': -10.657235825223923},
#   'meet': {'count': 28, 'probability': -8.67623435635734},
#   'metaphys': {'count': 0, 'probability': -12.043530186343814},
#   'someon': {'count': 67, 'probability': -7.824022481167707},
#   'disclaim': {'count': 22, 'probability': -8.908035970414664},
#   'caus': {'count': 247, 'probability': -6.530101440178831},
#   'unknow': {'count': 0, 'probability': -12.043530186343814},
#   'thus': {'count': 15, 'probability': -9.270941464104032},
#   'cannot': {'count': 34, 'probability': -8.4881821248544},
#   'slipperi': {'count': 0, 'probability': -12.043530186343814},
#   'languag': {'count': 20, 'probability': -8.999007748620391},
#   'inexact': {'count': 0, 'probability': -12.043530186343814},
#   'bewar': {'count': 0, 'probability': -12.043530186343814},
#   'point': {'count': 109, 'probability': -7.343049820551397},
#   'fact': {'count': 99, 'probability': -7.438360000355722},
#   'call': {'count': 140, 'probability': -7.094770295965645},
#   'shade': {'count': 3, 'probability': -10.657235825223923},
#   'certain': {'count': 116, 'probability': -7.2813562515460575},
#   'scienc': {'count': 209, 'probability': -6.696422655626345},
#   'find': {'count': 147, 'probability': -7.046317912579699},
#   'basi': {'count': 22, 'probability': -8.908035970414664},
#   'choos': {'count': 12, 'probability': -9.478580828882277},
#   'feel': {'count': 68, 'probability': -7.809423681746554},
#   'major': {'count': 67, 'probability': -7.824022481167707},
#   'essenti': {'count': 38, 'probability': -8.379968540214168},
#   'self': {'count': 17, 'probability': -9.15315842844765},
#   'contradictori': {'count': 0, 'probability': -12.043530186343814},
#   'logic': {'count': 24, 'probability': -8.824654361475613},
#   'imposs': {'count': 19, 'probability': -9.047797912789823},
#   'could': {'count': 171, 'probability': -6.896035709530361},
#   'evid': {'count': 112, 'probability': -7.316142367631473},
#   'prove': {'count': 25, 'probability': -8.785433648322332},
#   'counter': {'count': 7, 'probability': -9.964088644663978},
#   'prime': {'count': 0, 'probability': -12.043530186343814},
#   'larger': {'count': 7, 'probability': -9.964088644663978},
#   'cours': {'count': 111, 'probability': -7.32503131504872},
#   'deal': {'count': 38, 'probability': -8.379968540214168},
#   'object': {'count': 58, 'probability': -7.965992742438094},
#   'obey': {'count': 2, 'probability': -10.944917897675705},
#   'rule': {'count': 21, 'probability': -8.952487732985498},
#   'matter': {'count': 45, 'probability': -8.214888789854719},
#   'debat': {'count': 5, 'probability': -10.25177071711576},
#   'moment': {'count': 5, 'probability': -10.25177071711576},
#   'provabl': {'count': 0, 'probability': -12.043530186343814},
#   'still': {'count': 107, 'probability': -7.361398959219594},
#   'subtl': {'count': 1, 'probability': -11.350383005783868},
#   'show': {'count': 96, 'probability': -7.468819207840431},
#   'assumpt': {'count': 9, 'probability': -9.740945093349769},
#   'invalid': {'count': 0, 'probability': -12.043530186343814},
#   'requir': {'count': 63, 'probability': -7.884647102984142},
#   'exhaust': {'count': 3, 'probability': -10.657235825223923},
#   'might': {'count': 113, 'probability': -7.307331737949318},
#   'impract': {'count': 0, 'probability': -12.043530186343814},
#   'problem': {'count': 251, 'probability': -6.51410109883239},
#   'largest': {'count': 3, 'probability': -10.657235825223923},
#   'therefor': {'count': 25, 'probability': -8.785433648322332},
#   'accept': {'count': 58, 'probability': -7.965992742438094},
#   'unless': {'count': 54, 'probability': -8.036197001111343},
#   'unicorn': {'count': 0, 'probability': -12.043530186343814},
#   'though': {'count': 72, 'probability': -7.753070745195423},
#   'anywher': {'count': 8, 'probability': -9.846305609007594},
#   'test': {'count': 166, 'probability': -6.925536373927058},
#   'everywher': {'count': 4, 'probability': -10.434092273909714},
#   'default': {'count': 0, 'probability': -12.043530186343814},
#   'profess': {'count': 8, 'probability': -9.846305609007594},
#   'usual': {'count': 92, 'probability': -7.5109306931905575},
#   'claim': {'count': 56, 'probability': -8.000478918509263},
#   'instead': {'count': 20, 'probability': -8.999007748620391},
#   'restrict': {'count': 24, 'probability': -8.824654361475613},
#   'varieti': {'count': 9, 'probability': -9.740945093349769},
#   'practic': {'count': 49, 'probability': -8.131507180915667},
#   'suffici': {'count': 11, 'probability': -9.558623536555814},
#   'disprov': {'count': 14, 'probability': -9.335479985241603},
#   'everi': {'count': 93, 'probability': -7.50023540407381},
#   'realli': {'count': 119, 'probability': -7.256038443561768},
#   'applic': {'count': 25, 'probability': -8.785433648322332},
#   'detect': {'count': 16, 'probability': -9.210316842287597},
#   'interact': {'count': 6, 'probability': -10.0976200372885},
#   'measur': {'count': 19, 'probability': -9.047797912789823},
#   'henc': {'count': 3, 'probability': -10.657235825223923},
#   'easili': {'count': 15, 'probability': -9.270941464104032},
#   'israelit': {'count': 0, 'probability': -12.043530186343814},
#   'today': {'count': 32, 'probability': -8.547022624877334},
#   'scientif': {'count': 120, 'probability': -7.247739640747072},
#   'verifi': {'count': 6, 'probability': -10.0976200372885},
#   'physic': {'count': 36, 'probability': -8.43261227369959},
#   'perceiv': {'count': 4, 'probability': -10.434092273909714},
#   'presenc': {'count': 6, 'probability': -10.0976200372885},
#   'otherwis': {'count': 33, 'probability': -8.517169661727653},
#   'distinguish': {'count': 10, 'probability': -9.645634913545443},
#   'ok': {'count': 15, 'probability': -9.270941464104032},
#   'common': {'count': 83, 'probability': -7.6127133875005},
#   'pastim': {'count': 0, 'probability': -12.043530186343814},
#   'redefinit': {'count': 0, 'probability': -12.043530186343814},
#   'game': {'count': 1, 'probability': -11.350383005783868},
#   'cynic': {'count': 0, 'probability': -12.043530186343814},
#   'gradual': {'count': 4, 'probability': -10.434092273909714},
#   'arriv': {'count': 3, 'probability': -10.657235825223923},
#   'prepar': {'count': 21, 'probability': -8.952487732985498},
#   'record': {'count': 16, 'probability': -9.210316842287597},
#   'along': {'count': 26, 'probability': -8.747693320339485},
#   'agre': {'count': 37, 'probability': -8.405944026617428},
#   'continu': {'count': 49, 'probability': -8.131507180915667},
#   'eventu': {'count': 21, 'probability': -8.952487732985498},
#   'need': {'count': 137, 'probability': -7.116276501186609},
#   'seen': {'count': 58, 'probability': -7.965992742438094},
#   'appar': {'count': 47, 'probability': -8.172329175435923},
#   'inconsist': {'count': 0, 'probability': -12.043530186343814},
#   'tend': {'count': 33, 'probability': -8.517169661727653},
#   'play': {'count': 25, 'probability': -8.785433648322332},
#   'digress': {'count': 2, 'probability': -10.944917897675705},
#   'depend': {'count': 30, 'probability': -8.609542981858667},
#   'crucial': {'count': 5, 'probability': -10.25177071711576},
#   'meant': {'count': 12, 'probability': -9.478580828882277},
#   'control': {'count': 112, 'probability': -7.316142367631473},
#   'power': {'count': 26, 'probability': -8.747693320339485},
#   'especi': {'count': 48, 'probability': -8.151709888233187},
#   'worship': {'count': 2, 'probability': -10.944917897675705},
#   'pass': {'count': 14, 'probability': -9.335479985241603},
#   'buddhism': {'count': 0, 'probability': -12.043530186343814},
#   'accord': {'count': 19, 'probability': -9.047797912789823},
#   'categor': {'count': 2, 'probability': -10.944917897675705},
#   'meaning': {'count': 0, 'probability': -12.043530186343814},
#   'widen': {'count': 1, 'probability': -11.350383005783868},
#   'encompass': {'count': 2, 'probability': -10.944917897675705},
#   'result': {'count': 144, 'probability': -7.06679644392324},
#   'aspect': {'count': 8, 'probability': -9.846305609007594},
#   'behaviour': {'count': 1, 'probability': -11.350383005783868},
#   'sudden': {'count': 20, 'probability': -8.999007748620391},
#   'class': {'count': 11, 'probability': -9.558623536555814},
#   'polit': {'count': 11, 'probability': -9.558623536555814},
#   'watch': {'count': 23, 'probability': -8.865476355995868},
#   'tv': {'count': 2, 'probability': -10.944917897675705},
#   'act': {'count': 16, 'probability': -9.210316842287597},
#   'entir': {'count': 19, 'probability': -9.047797912789823},
#   'clear': {'count': 49, 'probability': -8.131507180915667},
#   'necessari': {'count': 25, 'probability': -8.785433648322332},
#   'adopt': {'count': 2, 'probability': -10.944917897675705},
#   'core': {'count': 6, 'probability': -10.0976200372885},
#   'sensori': {'count': 3, 'probability': -10.657235825223923},
#   'data': {'count': 49, 'probability': -8.131507180915667},
#   'experi': {'count': 124, 'probability': -7.215216449041512},
#   'throw': {'count': 9, 'probability': -9.740945093349769},
#   'doubt': {'count': 18, 'probability': -9.099091207177374},
#   'law': {'count': 40, 'probability': -8.329958119639507},
#   'basic': {'count': 48, 'probability': -8.151709888233187},
#   'almost': {'count': 43, 'probability': -8.259340552425552},
#   'everyth': {'count': 38, 'probability': -8.379968540214168},
#   'said': {'count': 110, 'probability': -7.33399998503148},
#   'lose': {'count': 9, 'probability': -9.740945093349769},
#   'complet': {'count': 52, 'probability': -8.073238272791691},
#   'individu': {'count': 28, 'probability': -8.67623435635734},
#   'scientist': {'count': 75, 'probability': -7.712796846057483},
#   'tendenc': {'count': 3, 'probability': -10.657235825223923},
#   'reluct': {'count': 2, 'probability': -10.944917897675705},
#   'certainti': {'count': 6, 'probability': -10.0976200372885},
#   'support': {'count': 69, 'probability': -7.795034944294454},
#   'fit': {'count': 20, 'probability': -8.999007748620391},
#   'closer': {'count': 7, 'probability': -9.964088644663978},
#   'match': {'count': 17, 'probability': -9.15315842844765},
#   'experiment': {'count': 29, 'probability': -8.642332804681658},
#   'lack': {'count': 36, 'probability': -8.43261227369959},
#   'assert': {'count': 11, 'probability': -9.558623536555814},
#   'anti': {'count': 60, 'probability': -7.932656322170502},
#   'label': {'count': 8, 'probability': -9.846305609007594},
#   'everyon': {'count': 19, 'probability': -9.047797912789823},
#   'either': {'count': 52, 'probability': -8.073238272791691},
#   'enemi': {'count': 0, 'probability': -12.043530186343814},
#   'cut': {'count': 25, 'probability': -8.785433648322332},
#   'run': {'count': 46, 'probability': -8.193382584633756},
#   'speak': {'count': 25, 'probability': -8.785433648322332},
#   'antipathi': {'count': 0, 'probability': -12.043530186343814},
#   'hatr': {'count': 7, 'probability': -9.964088644663978},
#   'hostil': {'count': 2, 'probability': -10.944917897675705},
#   'unfair': {'count': 1, 'probability': -11.350383005783868},
#   'attitud': {'count': 11, 'probability': -9.558623536555814},
#   'broad': {'count': 10, 'probability': -9.645634913545443},
#   'spectrum': {'count': 16, 'probability': -9.210316842287597},
#   'let': {'count': 52, 'probability': -8.073238272791691},
#   'mention': {'count': 44, 'probability': -8.236867696573494},
#   'except': {'count': 37, 'probability': -8.405944026617428},
#   'perhap': {'count': 57, 'probability': -7.983087175797395},
#   'part': {'count': 89, 'probability': -7.543720516013549},
#   'social': {'count': 14, 'probability': -9.335479985241603},
#   'countri': {'count': 23, 'probability': -8.865476355995868},
#   'convert': {'count': 9, 'probability': -9.740945093349769},
#   'histor': {'count': 4, 'probability': -10.434092273909714},
#   'made': {'count': 82, 'probability': -7.6246895785472155},
#   'littl': {'count': 73, 'probability': -7.739465093139644},
#   'impact': {'count': 11, 'probability': -9.558623536555814},
#   'outsid': {'count': 15, 'probability': -9.270941464104032},
#   'eastern': {'count': 1, 'probability': -11.350383005783868},
#   'bloc': {'count': 0, 'probability': -12.043530186343814},
#   'slight': {'count': 16, 'probability': -9.210316842287597},
#   'soviet': {'count': 6, 'probability': -10.0976200372885},
#   'union': {'count': 5, 'probability': -10.25177071711576},
#   'dedic': {'count': 0, 'probability': -12.043530186343814},
#   'separ': {'count': 12, 'probability': -9.478580828882277},
#   'citizen': {'count': 16, 'probability': -9.210316842287597},
#   'free': {'count': 33, 'probability': -8.517169661727653},
#   'wish': {'count': 31, 'probability': -8.577794283544087},
#   'institut': {'count': 58, 'probability': -7.965992742438094},
#   'came': {'count': 29, 'probability': -8.642332804681658},
#   'stalin': {'count': 0, 'probability': -12.043530186343814},
#   'took': {'count': 28, 'probability': -8.67623435635734},
#   'destroy': {'count': 6, 'probability': -10.0976200372885},
#   'order': {'count': 59, 'probability': -7.949185624121713},
#   'gain': {'count': 43, 'probability': -8.259340552425552},
#   'popul': {'count': 25, 'probability': -8.785433648322332},
#   'vocal': {'count': 2, 'probability': -10.944917897675705},
#   'encroach': {'count': 0, 'probability': -12.043530186343814},
#   'busi': {'count': 28, 'probability': -8.67623435635734},
#   'govern': {'count': 4, 'probability': -10.434092273909714},
#   'concern': {'count': 65, 'probability': -7.853875444317389},
#   'allow': {'count': 42, 'probability': -8.282330070650252},
#   'principl': {'count': 6, 'probability': -10.0976200372885},
#   'shall': {'count': 5, 'probability': -10.25177071711576},
#   'legisl': {'count': 4, 'probability': -10.434092273909714},
#   'expens': {'count': 30, 'probability': -8.609542981858667},
#   'natur': {'count': 90, 'probability': -7.532670679826964},
#   'pure': {'count': 20, 'probability': -8.999007748620391},
#   'respons': {'count': 95, 'probability': -7.479181994875978},
#   'reform': {'count': 4, 'probability': -10.434092273909714},
#   'campaign': {'count': 1, 'probability': -11.350383005783868},
#   'increas': {'count': 97, 'probability': -7.4585627076732415},
#   'spend': {'count': 14, 'probability': -9.335479985241603},
#   'foreign': {'count': 3, 'probability': -10.657235825223923},
#   'aid': {'count': 101, 'probability': -7.418557373059543},
#   'long': {'count': 128, 'probability': -7.183717781982142},
#   'discrimin': {'count': 4, 'probability': -10.434092273909714},
#   'ground': {'count': 16, 'probability': -9.210316842287597},
#   'happi': {'count': 14, 'probability': -9.335479985241603},
#   'prayer': {'count': 0, 'probability': -12.043530186343814},
#   'school': {'count': 57, 'probability': -7.983087175797395},
#   'care': {'count': 114, 'probability': -7.298598057980564},
#   'pray': {'count': 1, 'probability': -11.350383005783868},
#   'voter': {'count': 0, 'probability': -12.043530186343814},
#   'lawmak': {'count': 0, 'probability': -12.043530186343814},
#   'ignor': {'count': 17, 'probability': -9.15315842844765},
#   'intimid': {'count': 0, 'probability': -12.043530186343814},
#   'told': {'count': 56, 'probability': -8.000478918509263},
#   'join': {'count': 6, 'probability': -10.0976200372885},
#   'divers': {'count': 1, 'probability': -11.350383005783868},
#   'formul': {'count': 1, 'probability': -11.350383005783868},
#   'public': {'count': 91, 'probability': -7.521741609294773},
#   'famili': {'count': 39, 'probability': -8.354650732229878},
#   'wast': {'count': 18, 'probability': -9.099091207177374},
#   'motiv': {'count': 18, 'probability': -9.099091207177374},
#   'chariti': {'count': 0, 'probability': -12.043530186343814},
#   'hospit': {'count': 56, 'probability': -8.000478918509263},
#   'purpos': {'count': 30, 'probability': -8.609542981858667},
#   'contribut': {'count': 13, 'probability': -9.404472856728555},
#   'sake': {'count': 4, 'probability': -10.434092273909714},
#   'good': {'count': 204, 'probability': -6.720520207205405},
#   'voluntari': {'count': 1, 'probability': -11.350383005783868},
#   'theistic': {'count': 0, 'probability': -12.043530186343814},
#   'shout': {'count': 0, 'probability': -12.043530186343814},
#   ...}]

# %%
len(vocabStopStemmingEdit)
"worshipped" in vocabStopEdit
# Out:
# True
