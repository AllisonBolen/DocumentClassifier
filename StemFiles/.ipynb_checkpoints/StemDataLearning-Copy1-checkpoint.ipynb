# %%
# get imports # import files
from threading import Thread
import queue as que
import pandas as pd
import os, pickle
import nltk
import math
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
from collections import Counter 

stemmer = PorterStemmer()
cachedStopWords = stopwords.words("english")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2e8f9eb48cf0> in <module>()
#      11 from collections import Counter
#      12
# ---> 13 stemmer = PorterStemmer("english")
#      14 cachedStopWords = stopwords.words("english")
#
# NameError: name 'PorterStemmer' is not defined

# %%
#methods
def save_it_all(obj, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
    
def load_objects(file):
    with open(file, 'rb') as input:
        return pickle.load(input)
    
def merge_two_dicts(x, y):
    z = x.copy()   # start with x's keys and values
    z.update(y)    # modifies z with y's keys and values & returns None
    return z

def seperator(docs):
    print(len(docs))
    txt = []
    typesInfo = []
    docsInfo = []
    for line in docs:
        words = line.split()
        content = (" ").join(words[1:])
        item = (", ").join([words[0], content])
        txt.append(item)
        typesInfo.append(words[0])
        docsInfo.append(content)
    return txt, typesInfo, docsInfo

def write(data):
    print(type(data))
    with open('./training_data.csv', 'w') as f:
        for item in data:
            f.write("%s\n" % item)
            
# methods
def read(fileName):
    with open(fileName) as f:
        content = f.readlines()
    # you may also want to remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    return content

def save_it_all(obj, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
    
def load_objects(file):
    with open(file, 'rb') as input:
        return pickle.load(input)
    
def vocabDict(vocab, n): # handles empty word sets
    nk = 0
    # n = the number of word postions for this document type
    probability = ((nk + 1) / (n + len(vocab)))

    newDict = {"count": 0, "probability":probability}
    vdict = dict((el,newDict) for el in vocab)
    return vdict

def wordCount(doc, vocab, n): # get actual word count for each word and create dict frame to track the info
    counts = dict(Counter(doc.tolist()[0].split()))
    for key, value in counts.items():
        nk = value
        probability = ((nk + 1) / (n + len(vocab)))
        newDict = {"count": nk, "probability": probability}
        counts[key] = newDict
    emptyVocab = vocabDict(vocab, n)
    dicts = [merge_two_dicts(emptyVocab, counts)]
    return dicts
    

def saveFrame(df, name):
    df.to_csv(name+".csv", index=False, sep=",", header=True)
    save_it_all(df, name+".pkl")

# %%
# # load in files 
# # read file line by line 
# fileName = "../forumTraining.data"
# data = read(fileName)
# len(data)
# sep_data, typesInfo, docsInfo = seperator(data)
# # write(sep_data) not needed the raw csv it makes IS BROKEN
# # print(len(list(set(typesInfo))))
# # print(list(set(typesInfo)))
# dataFrameRaw = pd.DataFrame({"Type": typesInfo, "Document": docsInfo})
# saveFrame(dataFrameRaw, "raw_training_data.csv")

# %%
raw_training_data = pd.read_csv("../RawFiles/raw_training_data.csv", sep=",")
raw_training_data.head()
# Out:
#       Type                                           Document
# 0  atheism  alt atheism faq atheist resources archive name...
# 1  atheism  alt atheism faq introduction to atheism archiv...
# 2  atheism  re gospel dating in article mimsy umd edu mang...
# 3  atheism  re university violating separation of church s...
# 4  atheism  re soc motss et al princeton axes matching fun...

# %% [markdown]
# ### Trianing data raw is held in the dataframe "raw_training_data"

# %%
# create the raw vocabulary set:
raw_vocabulary = " ".join(raw_training_data["Document"].tolist()) # concatinates all documents in the data frame
raw_vocabulary = list(set(raw_vocabulary.split()))
print(len(raw_vocabulary))
# save_it_all(raw_vocabulary, "./raw_vocabulary.pkl")
# Out:
# 73712

# %% [markdown]
# ### The raw vocabulary is saved in the above cell and refrenced as "raw_vocabulary"

# %% [markdown]
# # This is the learning step: make it dynamic!
# For each class cj (document type) in C
#
#     1. Docsj ← training documents for which the classification is cj
#
#     2. Probability estimate of a particular class: P(cj) = |Docsj| / |training documents|
#
#     3. Textj ← create a single document per class (concatenate all Docsj)
#
#     4. n = total number of word positions in Textj
#
#     5. For each word wk in Vocabulary nk = number of times wk occurs in Textj
#
#     6. Estimate of word occurrence for particular document type: P(wk | cj) = (nk + 1) / (n + |Vocabulary|)
#
# Probability of kth word in vocabulary, given a document of type j

# %%
# load in docs you want to use:
## trainign data set for use:
trainFrame = pd.read_csv("../RawFiles/raw_training_data.csv", sep=",")

## vocabulary training set for use:
vocabulary = load_objects("../RawFiles/raw_vocabulary.pkl")

# validate:
print(type(vocabulary))
trainFrame.head()
# Out:
# <class 'list'>
#       Type                                           Document
# 0  atheism  alt atheism faq atheist resources archive name...
# 1  atheism  alt atheism faq introduction to atheism archiv...
# 2  atheism  re gospel dating in article mimsy umd edu mang...
# 3  atheism  re university violating separation of church s...
# 4  atheism  re soc motss et al princeton axes matching fun...

# %%
# single docs per class
types = list(set(trainFrame["Type"]))
singleFrame = pd.DataFrame({"Type":types , "Document": None})
# singleFrame.head(20)
for docType in singleFrame["Type"]:
    #print(trainFrame["Document"][trainFrame["Type"]==docType])
    singleFrame["Document"][singleFrame["Type"]== docType] = " ".join(trainFrame["Document"][trainFrame["Type"]==docType].tolist())
singleFrame.head(30)
singleFrame["Type"].tolist()
# Out:
# ['autos',
#  'electronics',
#  'mac',
#  'pc',
#  'politics',
#  'baseball',
#  'motorcycles',
#  'mswindows',
#  'forsale',
#  'cryptology',
#  'christianity',
#  'guns',
#  'hockey',
#  'mideastpolitics',
#  'religion',
#  'xwindows',
#  'medicine',
#  'space',
#  'atheism',
#  'graphics']

# %%
# make a copy of the single frame 
rawDataInfoFrame = singleFrame.copy()

# %%
# probability estimate of the class
rawDataInfoFrame["ClassProbability"] = None
for docType in rawDataInfoFrame["Type"]:
    rawDataInfoFrame["ClassProbability"][rawDataInfoFrame["Type"]== docType] = len(trainFrame["Document"][trainFrame["Type"]== docType].tolist()) / trainFrame["Type"].count()

# %%
rawDataInfoFrame.head()
# Out:
#           Type                                           Document  \
# 0        autos  re saturn s pricing policy in article c vir l ...
# 1  electronics  re help with tracking device in article fba e ...
# 2          mac  re nutek faces apple s wrath article read in a...
# 3           pc  wanted bus card for logitech mouse i ve acquir...
# 4     politics  re media horrified at perot investigating bush...
#
#   ClassProbability
# 0         0.052599
# 1        0.0523333
# 2        0.0511821
# 3        0.0522448
# 4        0.0411759

# %%
# get the word postions:
rawDataInfoFrame["WordPositions"] = None
for docType in rawDataInfoFrame["Type"]:
    rawDataInfoFrame["WordPositions"][rawDataInfoFrame["Type"]== docType] = len(rawDataInfoFrame["Document"][rawDataInfoFrame["Type"]== docType].tolist()[0].split())

# %%
rawDataInfoFrame.head(20)
# Out:
#                Type                                           Document  \
# 0             autos  re saturn s pricing policy in article c vir l ...
# 1       electronics  re help with tracking device in article fba e ...
# 2               mac  re nutek faces apple s wrath article read in a...
# 3                pc  wanted bus card for logitech mouse i ve acquir...
# 4          politics  re media horrified at perot investigating bush...
# 5          baseball  spring records the orioles pitching staff agai...
# 6       motorcycles  re lexan polish in article c soe m ns nodak ed...
# 7         mswindows  re is kermit available for windows from articl...
# 8           forsale  motorcycle wanted followup to kedz wpi wpi edu...
# 9        cryptology  ripem frequently asked questions archive name ...
# 10     christianity  re sex education in article mar athos rutgers ...
# 11             guns  re gun control was re we re mad as hell at the...
# 12           hockey  superstars and attendance was teemu selanne wa...
# 13  mideastpolitics  re islam borders was israel misisipi to ganges...
# 14         religion  re religion and homosexuality magarret magnus ...
# 15         xwindows  th international obfuscated c code contest ope...
# 16         medicine  info needed gaucher s disease i have a yr old ...
# 17            space  re gravity waves was predicting gravity wave q...
# 18          atheism  alt atheism faq atheist resources archive name...
# 19         graphics  call for presentations navy sciviz vr seminar ...
#
#    ClassProbability WordPositions
# 0          0.052599        127696
# 1         0.0523333        115503
# 2         0.0511821         97182
# 3         0.0522448        112583
# 4         0.0411759        202625
# 5         0.0528646        119407
# 6         0.0529532        115430
# 7         0.0506508         95238
# 8          0.051802         69761
# 9         0.0526875        219507
# 10        0.0529532        216581
# 11          0.04826        191723
# 12        0.0531303        153949
# 13        0.0499424        272488
# 14        0.0333835        129611
# 15        0.0525104        175024
# 16         0.052599        170336
# 17        0.0525104        168481
# 18        0.0425042        161442
# 19        0.0517135        123428

# %%
# word count 
rawDataInfoFrame["WordCount"] = None
for docType in rawDataInfoFrame["Type"]:
    n = rawDataInfoFrame["WordPositions"][rawDataInfoFrame["Type"] == docType].tolist()[0]
    print(n)
    rawDataInfoFrame["WordCount"][rawDataInfoFrame["Type"] == docType] = wordCount(rawDataInfoFrame["Document"][rawDataInfoFrame["Type"]==docType], vocabulary, n)
# Out:
# 127696
# 115503
# 97182
# 112583
# 202625
# 119407
# 115430
# 95238
# 69761
# 219507
# 216581
# 191723
# 153949
# 272488
# 129611
# 175024
# 170336
# 168481
# 161442
# 123428

# %%
rawDataInfoFrame.head()
#rawDataInfoFrame["WordCount"][rawDataInfoFrame["Type"] == "graphics"].tolist()[0]
# Out:
#           Type                                           Document  \
# 0        autos  re saturn s pricing policy in article c vir l ...
# 1  electronics  re help with tracking device in article fba e ...
# 2          mac  re nutek faces apple s wrath article read in a...
# 3           pc  wanted bus card for logitech mouse i ve acquir...
# 4     politics  re media horrified at perot investigating bush...
#
#   ClassProbability WordPositions  \
# 0         0.052599        127696
# 1        0.0523333        115503
# 2        0.0511821         97182
# 3        0.0522448        112583
# 4        0.0411759        202625
#
#                                            WordCount
# 0  {'hepis': {'count': 0, 'probability': 4.965046...
# 1  {'hepis': {'count': 0, 'probability': 5.284993...
# 2  {'hepis': {'count': 0, 'probability': 5.851580...
# 3  {'hepis': {'count': 0, 'probability': 5.367830...
# 4  {'hepis': {'count': 0, 'probability': 3.618769...

# %%
saveFrame(rawDataInfoFrame, "./raw_data_info_frame")

# %% [markdown]
# ### Removeing Stem words from the stuff

# %%
## get a vocab set of removed stop words and the train frame with removed stop words
# remove stop words
stem_training_data = singleFrame.copy()
for docType in stem_training_data["Type"]:
    text = stem_training_data["Document"][stem_training_data["Type"]==docType].tolist()[0]
    stem_training_data["Document"][stem_training_data["Type"]==docType] = ' '.join([stemmer.stem(word) for word in text.split()])

stem_vocabulary = []
stem_vocabulary = set([stemmer.stem(word) for word in text.split()])
len(stem_vocabulary)

len(stem_vocabulary)
#stop_training_data.head()
# Out:
# 8568

# %%
# probability estimate of the class
stem_training_data["ClassProbability"] = None
for docType in stem_training_data["Type"]:
    stem_training_data["ClassProbability"][stem_training_data["Type"]== docType] = len(trainFrame["Document"][trainFrame["Type"]== docType].tolist()) / trainFrame["Type"].count()

# %%
stem_training_data.head()
# Out:
#           Type                                           Document  \
# 0        autos  re saturn s price polici in articl c vir l r s...
# 1  electronics  re help with track devic in articl fba e ff ae...
# 2          mac  re nutek face appl s wrath articl read in arti...
# 3           pc  want bus card for logitech mous i ve acquir an...
# 4     politics  re media horrifi at perot investig bush visser...
#
#   ClassProbability
# 0         0.052599
# 1        0.0523333
# 2        0.0511821
# 3        0.0522448
# 4        0.0411759

# %%
# get the word postions:
stem_training_data["WordPositions"] = None
for docType in stem_training_data["Type"]:
    stem_training_data["WordPositions"][stem_training_data["Type"]== docType] = len(stem_training_data["Document"][stem_training_data["Type"]== docType].tolist()[0].split())

# %%
stem_training_data.head()
# Out:
#           Type                                           Document  \
# 0        autos  re saturn s price polici in articl c vir l r s...
# 1  electronics  re help with track devic in articl fba e ff ae...
# 2          mac  re nutek face appl s wrath articl read in arti...
# 3           pc  want bus card for logitech mous i ve acquir an...
# 4     politics  re media horrifi at perot investig bush visser...
#
#   ClassProbability WordPositions
# 0         0.052599        127696
# 1        0.0523333        115503
# 2        0.0511821         97182
# 3        0.0522448        112583
# 4        0.0411759        202625

# %%
# word count 
stem_training_data["WordCount"] = None
for docType in stem_training_data["Type"]:
    n = stem_training_data["WordPositions"][stem_training_data["Type"] == docType].tolist()[0]
    print(n)
    stem_training_data["WordCount"][stem_training_data["Type"] == docType] = wordCount(stem_training_data["Document"][stem_training_data["Type"]==docType], stem_vocabulary, n)
# Out:
# 127696
# 115503
# 97182
# 112583
# 202625
# 119407
# 115430
# 95238
# 69761
# 219507
# 216581
# 191723
# 153949
# 272488
# 129611
# 175024
# 170336
# 168481
# 161442
# 123428

# %%
stem_training_data.head()
# Out:
#           Type                                           Document  \
# 0        autos  re saturn s price polici in articl c vir l r s...
# 1  electronics  re help with track devic in articl fba e ff ae...
# 2          mac  re nutek face appl s wrath articl read in arti...
# 3           pc  want bus card for logitech mous i ve acquir an...
# 4     politics  re media horrifi at perot investig bush visser...
#
#   ClassProbability WordPositions  \
# 0         0.052599        127696
# 1        0.0523333        115503
# 2        0.0511821         97182
# 3        0.0522448        112583
# 4        0.0411759        202625
#
#                                            WordCount
# 0  {'repacholi': {'count': 0, 'probability': 4.96...
# 1  {'repacholi': {'count': 0, 'probability': 5.28...
# 2  {'repacholi': {'count': 0, 'probability': 5.85...
# 3  {'repacholi': {'count': 0, 'probability': 5.37...
# 4  {'repacholi': {'count': 0, 'probability': 3.62...

# %%
saveFrame(stem_training_data, "./stem_training_data")
save_it_all(stem_vocabulary, "./stem_vocabulary.pkl")
